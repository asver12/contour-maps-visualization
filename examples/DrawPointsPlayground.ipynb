# %%
from contour_visualization import picture_plot
from contour_visualization import example_data

import matplotlib.pyplot as plt
import matplotlib.markers as mkr

# %%
# For autotesting
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
gaussians_example = example_data.generate_four_random_gaussians(size=100)
new_gau = gaussians_example[24:25]

# %%
new_gau[0][::-1]
# Out:
# [<contour_visualization.Gaussian.Gaussian at 0x7f544887e340>,
#  <contour_visualization.Gaussian.Gaussian at 0x7f54488a84f0>,
#  <contour_visualization.Gaussian.Gaussian at 0x7f5448969dc0>,
#  <contour_visualization.Gaussian.Gaussian at 0x7f54489693a0>]

# %%
width = 6.0
height = 4.0
plt.rcParams['figure.figsize'] = [width, height]
plt.rcParams["xtick.major.bottom"] = False
plt.rcParams["ytick.minor.left"] = False
plt.rcParams["ytick.major.left"] = False
plt.rcParams['legend.fontsize'] = 25
plt.rcParams['legend.handlelength'] = 3
plt.rcParams['legend.numpoints'] = 1
plt.rcParams["legend.markerscale"] = 1.0
plt.rcParams["legend.frameon"] = True
plt.rcParams["legend.loc"] = "upper right"

# %%
dist_params = {
    "scatter_points": True,
    "scatter_points_num": 20,
}

vis_params = {
    "xlim": [-7.5,12.5],
    "ylim": [-10. , 10],
    "marker": "v",
    "edge_colors": True,
    "face_colors": False,
}

# %%
picture_plot.plot_images([new_gau[0][::-1]], **vis_params, **dist_params)

# %%
fig, ax = plt.subplots(1,1)
picture_plot.plot_image(ax, new_gau[0][::-1], **vis_params, **dist_params)
