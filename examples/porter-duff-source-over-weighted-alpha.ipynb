# %% [markdown]
# # Weighted Alpha-Blending
# Mixing colors weighted by their function value at each point

# %%
from matplotlib import pyplot as plt
from numpy.random import randn
# %matplotlib inline
import numpy as np
from skimage import color

from src import hierarchic_blending_operator
from src import color_converter
from src import color_operations
from src import color_schemes
from src import picture_worker
from src import helper

# %% [markdown]
# ## Monochromatic start colors

# %%
first_start_color = [1,0,0,1]
second_start_color = [0,1,0,1]
third_start_color = [0,0,1,1]

# %% [markdown]
# ## Matplotlib color-schemes

# %%
first_color_scheme = "PuBu"
second_color_scheme = "OrRd"
third_color_scheme = "RdPu"

# %%
x_min, x_max = -10, 10
y_min, y_max = -10, 10
size = 200

mu_x_1 = 0
mu_y_1 = 0
mu_variance_x_1 = 3
mu_variance_y_1 = 15
gaussian_1 = (mu_x_1,mu_variance_x_1,mu_y_1,mu_variance_y_1)
mu_x_2 = 3
mu_y_2 = 3
mu_variance_x_2 = 4
mu_variance_y_2 = 4
gaussian_2 = (mu_x_2,mu_variance_x_2,mu_y_2,mu_variance_y_2)
mu_x_3 = -2
mu_y_3 = -1
mu_variance_x_3 = 7
mu_variance_y_3 = 7
gaussian_3 = (mu_x_3,mu_variance_x_3,mu_y_3,mu_variance_y_3)

# %%
X, Y, Z = helper.get_gaussian(x_min,x_max,y_min,y_max,*gaussian_1,size)
X_1, Y_1, Z_1 = helper.get_gaussian(x_min,x_max,y_min,y_max,*gaussian_2,size)
X_2, Y_2, Z_2 = helper.get_gaussian(x_min,x_max,y_min,y_max,*gaussian_3,size)

# %% [markdown]
# # Mixing the colors in RGB

# %% [markdown]
# ## Matplotlib color-schemes

# %%
Z_new, Z_alpha = picture_worker.get_colorgrid(Z,color_schemes.matplotlib_colorschemes,10,colorscheme=first_color_scheme)
Z_new_1, Z_alpha_1 = picture_worker.get_colorgrid(Z_1,color_schemes.matplotlib_colorschemes,10,colorscheme=second_color_scheme)
Z_new_2, Z_alpha_2 = picture_worker.get_colorgrid(Z_2,color_schemes.matplotlib_colorschemes,10,colorscheme=third_color_scheme)

# %%
mixed, alpha_new = picture_worker.combine_two_images_hierarchic(hierarchic_blending_operator.porter_duff_source_over, Z_new, Z, Z_new_1, Z_1)

# %%
mixed, _ = picture_worker.combine_two_images_hierarchic(hierarchic_blending_operator.porter_duff_source_over, mixed,alpha_new,Z_new_2,Z_2)

# %%
fig, (ax_0, ax_1, ax_2, ax_3) = plt.subplots(1,4)

# displays an image
ax_0.imshow(Z_new)
ax_0.axis("off")
ax_1.imshow(Z_new_1)
ax_1.axis("off")
ax_2.imshow(Z_new_2)
ax_2.axis("off")
ax_3.imshow(mixed)
ax_3.axis("off")
plt.subplots_adjust(0, 0, 1, 1)
plt.show()

# %%
#displays an image
plt.imshow(mixed)
plt.subplots_adjust(0, 0, 1, 1)
#plt.axis("off")
plt.show()

# %% [markdown]
# ## Monochromatic color-schemes

# %%
Z_new, Z_alpha = picture_worker.get_colorgrid(Z,color_schemes.create_monochromatic_colorscheme,10,False,startcolor=first_start_color, lvl_white = 1)
Z_new_1, Z_alpha_1 = picture_worker.get_colorgrid(Z_1,color_schemes.create_monochromatic_colorscheme,10,False,startcolor=second_start_color)
Z_new_2, Z_alpha_2 = picture_worker.get_colorgrid(Z_2,color_schemes.create_monochromatic_colorscheme,10,False,startcolor=third_start_color)

# %%
mixed, alpha_new = picture_worker.combine_two_images_hierarchic(hierarchic_blending_operator.porter_duff_source_over, Z_new, Z, Z_new_1, Z_1)

# %%
mixed, _ = picture_worker.combine_two_images_hierarchic(hierarchic_blending_operator.porter_duff_source_over, mixed,alpha_new,Z_new_2,Z_2)

# %%
fig, (ax_0, ax_1, ax_2, ax_3) = plt.subplots(1,4)

# displays an image
ax_0.imshow(Z_new)
ax_0.axis("off")
ax_1.imshow(Z_new_1)
ax_1.axis("off")
ax_2.imshow(Z_new_2)
ax_2.axis("off")
ax_3.imshow(mixed)
ax_3.axis("off")
plt.subplots_adjust(0, 0, 1, 1)
plt.show()

# %%
#displays an image
plt.imshow(mixed)
plt.subplots_adjust(0, 0, 1, 1)
#plt.axis("off")
plt.show()

# %% [markdown]
# # Mixing colors with hsv

# %% [markdown]
# ## Matplotlib color-schemes

# %%
Z_new, Z_alpha = picture_worker.get_colorgrid(Z,color_schemes.matplotlib_colorschemes,10,colorscheme=first_color_scheme)
Z_new_1, Z_alpha_1 = picture_worker.get_colorgrid(Z_1,color_schemes.matplotlib_colorschemes,10,colorscheme=second_color_scheme)
Z_new_2, Z_alpha_2 = picture_worker.get_colorgrid(Z_2,color_schemes.matplotlib_colorschemes,10,colorscheme=third_color_scheme)

# %%
mixed, alpha_new = picture_worker.combine_two_images_hierarchic(hierarchic_blending_operator.porter_duff_source_over, Z_new, Z, Z_new_1, Z_1,color_space = "hsv")

# %%
mixed, _ = picture_worker.combine_two_images_hierarchic(hierarchic_blending_operator.porter_duff_source_over, mixed,alpha_new,Z_new_2,Z_2,color_space = "hsv")

# %%
fig, (ax_0, ax_1, ax_2, ax_3) = plt.subplots(1,4)

# displays an image
ax_0.imshow(Z_new)
ax_0.axis("off")
ax_1.imshow(Z_new_1)
ax_1.axis("off")
ax_2.imshow(Z_new_2)
ax_2.axis("off")
ax_3.imshow(mixed)
ax_3.axis("off")
plt.subplots_adjust(0, 0, 1, 1)
plt.show()

# %%
#displays an image
plt.imshow(mixed)
plt.subplots_adjust(0, 0, 1, 1)
#plt.axis("off")
plt.show()

# %% [markdown]
# ## Monochromatic color schemes

# %%
Z_new, Z_alpha = picture_worker.get_colorgrid(Z,color_schemes.create_monochromatic_colorscheme,10,False,startcolor=first_start_color, lvl_white = 1)
Z_new_1, Z_alpha_1 = picture_worker.get_colorgrid(Z_1,color_schemes.create_monochromatic_colorscheme,10,False,startcolor=second_start_color)
Z_new_2, Z_alpha_2 = picture_worker.get_colorgrid(Z_2,color_schemes.create_monochromatic_colorscheme,10,False,startcolor=third_start_color)

# %%
mixed, alpha_new = picture_worker.combine_two_images_hierarchic(hierarchic_blending_operator.porter_duff_source_over, Z_new, Z, Z_new_1, Z_1,color_space = "hsv")

# %%
mixed, _ = picture_worker.combine_two_images_hierarchic(hierarchic_blending_operator.porter_duff_source_over, mixed,alpha_new,Z_new_2,Z_2,color_space = "hsv")

# %%
fig, (ax_0, ax_1, ax_2, ax_3) = plt.subplots(1,4)

# displays an image
ax_0.imshow(Z_new)
ax_0.axis("off")
ax_1.imshow(Z_new_1)
ax_1.axis("off")
ax_2.imshow(Z_new_2)
ax_2.axis("off")
ax_3.imshow(mixed)
ax_3.axis("off")
plt.subplots_adjust(0, 0, 1, 1)
plt.show()

# %%
#displays an image
plt.imshow(mixed)
plt.subplots_adjust(0, 0, 1, 1)
#plt.axis("off")
plt.show()

# %% [markdown]
# # Mixing colors with Lab

# %% [markdown]
# ## Matplotlib color-schemes

# %%
Z_new, Z_alpha = picture_worker.get_colorgrid(Z,color_schemes.matplotlib_colorschemes,10,colorscheme=first_color_scheme)
Z_new_1, Z_alpha_1 = picture_worker.get_colorgrid(Z_1,color_schemes.matplotlib_colorschemes,10,colorscheme=second_color_scheme)
Z_new_2, Z_alpha_2 = picture_worker.get_colorgrid(Z_2,color_schemes.matplotlib_colorschemes,10,colorscheme=third_color_scheme)

# %%
mixed, alpha_new = picture_worker.combine_two_images_hierarchic(hierarchic_blending_operator.porter_duff_source_over, Z_new, Z, Z_new_1, Z_1,color_space = "lab")

# %%
mixed, _ = picture_worker.combine_two_images_hierarchic(hierarchic_blending_operator.porter_duff_source_over, mixed,alpha_new,Z_new_2,Z_2,color_space = "lab")

# %%
fig, (ax_0, ax_1, ax_2, ax_3) = plt.subplots(1,4)

# displays an image
ax_0.imshow(Z_new)
ax_0.axis("off")
ax_1.imshow(Z_new_1)
ax_1.axis("off")
ax_2.imshow(Z_new_2)
ax_2.axis("off")
ax_3.imshow(mixed)
ax_3.axis("off")
plt.subplots_adjust(0, 0, 1, 1)
plt.show()

# %%
#displays an image
plt.imshow(mixed)
plt.subplots_adjust(0, 0, 1, 1)
#plt.axis("off")
plt.show()

# %% [markdown]
# ## Monochromatic color schemes

# %%
Z_new, Z_alpha = picture_worker.get_colorgrid(Z,color_schemes.create_monochromatic_colorscheme,10,False,startcolor=first_start_color, lvl_white = 1)
Z_new_1, Z_alpha_1 = picture_worker.get_colorgrid(Z_1,color_schemes.create_monochromatic_colorscheme,10,False,startcolor=second_start_color)
Z_new_2, Z_alpha_2 = picture_worker.get_colorgrid(Z_2,color_schemes.create_monochromatic_colorscheme,10,False,startcolor=third_start_color)

# %%
mixed, alpha_new = picture_worker.combine_two_images_hierarchic(hierarchic_blending_operator.porter_duff_source_over, Z_new, Z, Z_new_1, Z_1,color_space = "lab")

# %%
mixed, _ = picture_worker.combine_two_images_hierarchic(hierarchic_blending_operator.porter_duff_source_over, mixed,alpha_new,Z_new_2,Z_2,color_space = "lab")

# %%
fig, (ax_0, ax_1, ax_2, ax_3) = plt.subplots(1,4)

# displays an image
ax_0.imshow(Z_new)
ax_0.axis("off")
ax_1.imshow(Z_new_1)
ax_1.axis("off")
ax_2.imshow(Z_new_2)
ax_2.axis("off")
ax_3.imshow(mixed)
ax_3.axis("off")
plt.subplots_adjust(0, 0, 1, 1)
plt.show()

# %%
#displays an image
plt.imshow(mixed)
plt.subplots_adjust(0, 0, 1, 1)
#plt.axis("off")
plt.show()
