# %%
import pickle
import numpy as np
import itertools
import matplotlib.pyplot as plt

# %%
width = 19.5
height = 19.5
plt.rcParams['figure.figsize'] = [width, height]

# %%
from contour_visualization import ModelbaseDistribution, picture_plot, MixtureModel
# Out:
# 17:00:53.825 WARNING :: Using NumPy C-API based implementation for BLAS functions.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
model_allbus = pickle.load(open("../../fitted_models/mcg_allbus2_map.mdl", "rb"))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-a61fd33f9f1c> in <module>
# ----> 1 model_allbus = pickle.load(open("../../fitted_models/mcg_allbus2_map.mdl", "rb"))
#
# FileNotFoundError: [Errno 2] No such file or directory: '../../fitted_models/mcg_allbus2_map.mdl'

# %%
model_mcg = pickle.load(open("../../../fitted_models/mcg_mpg_map.mdl", "rb"))

# %%
model_allbus.data

# %%
dataset = []
for i in range(2,6):
    models, xlabels, ylabels = MixtureModel.generate_gaussian_plots(model_mcg.data, ["year", "mpg_city","mpg_highway","displacement"], n_components=i, size=1000)
    models_1, xlabels_1, ylabels_1 = MixtureModel.generate_gaussian_plots(model_allbus.data, ["age", "education","income","happiness","health"], n_components=i, size=1000)
    models.extend(models_1)
    xlabels.extend(xlabels_1)
    ylabels.extend(ylabels_1)
    dataset.append([models, xlabels, ylabels])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-f10e030da03a> in <module>
#       1 dataset = []
#       2 for i in range(2,6):
# ----> 3     models, xlabels, ylabels = MixtureModel.generate_gaussian_plots(model_mcg.data, ["year", "mpg_city","mpg_highway","displacement"], n_components=i, size=1000)
#       4     models_1, xlabels_1, ylabels_1 = MixtureModel.generate_gaussian_plots(model_allbus.data, ["age", "education","income","happiness","health"], n_components=i, size=1000)
#       5     models.extend(models_1)
#
# NameError: name 'model_mcg' is not defined

# %%
indices = {}
for ind, label in enumerate(zip(dataset[0][1],dataset[0][2])):
    indices["{}_{}".format(label[1],label[0])]=ind
    indices["{}_{}".format(label[0],label[1])]=ind
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-7-3cb49cafab8b> in <module>
#       1 indices = {}
# ----> 2 for ind, label in enumerate(zip(dataset[0][1],dataset[0][2])):
#       3     indices["{}_{}".format(label[1],label[0])]=ind
#       4     indices["{}_{}".format(label[0],label[1])]=ind
#
# IndexError: list index out of range

# %%
def plot_img_at_inds(dataset, inds, *args, **kwargs):
    figs = []
    axes = []
    for i in inds:
            fig, ax = picture_plot.plot_image_variations(dataset[0][i], xlabels=dataset[1][i], ylabels=dataset[2][i], *args, **kwargs)
            figs.append(fig)
            axes.append(ax)
    return figs, axes

# %%
def plot_img_at_inds_one(dataset, inds, *args, **kwargs):
    for i in inds:
            picture_plot.plot_images([dataset[0][i]], xlabels=dataset[1][i], ylabels=dataset[2][i], *args, **kwargs)

# %%
def get_indices(values):
    return [indices[i] for i in values]

# %%
img_inds = get_indices(["age_income"])

# %%
width = 18.5
height = 18.5
plt.rcParams['figure.figsize'] = [width, height]
# plt.rcParams['xtick.labelsize'] = 15
# plt.rcParams['ytick.labelsize'] = 15
plt.rcParams['legend.fontsize'] = 12
plt.rcParams['legend.handlelength'] = 2
plt.rcParams['axes.labelsize'] = 18
plt.rcParams['axes.titlesize'] = 25

# %%
fig, axes = plt.subplots(1,3)
# fig, axes = plot_img_at_inds(dataset[1], img_inds, contour_line_level=2, contour_method="equal_density")
axes[0].set_title("contour", pad=4)
axes[1].set_title("cross", pad=4)
axes[2].set_title("pie charts", pad=4)
# fig[0].tight_layout()
fig.savefig("three_modes_income_age.png")

# %%
fig, axes = plot_img_at_inds(dataset[2], img_inds, contour_line_level=2, contour_method="equal_density")
axes[0][0].set_title("contours", pad=4)
axes[0][1].set_title("crosses", pad=4)
axes[0][2].set_title("pie-charts", pad=4)
fig[0].tight_layout()
fig[0].savefig("four_modes_income_age.png")

# %%
fig, axes = plot_img_at_inds(dataset[3], img_inds, contour_line_level=2)
axes[0][0].set_title("contours", pad=4)
axes[0][1].set_title("crosses", pad=4)
axes[0][2].set_title("pie-charts", pad=4)
fig[0].tight_layout()
fig[0].savefig("five_modes_income_age.png")

# %%
img_inds = get_indices(["displacement_mpg_highway","age_income"])

# %%
plot_img_at_inds(dataset[2], img_inds, contour_line_level=2, contour_lower_border_lvl=12)

# %%
without_green = [dataset[2][0][img_inds[1]][i] for i in range(4) if i!=2]

# %% [markdown]
# The Enigma of Kaspar Hauser

# %%
plot_img_at_inds_one(dataset[2], [img_inds[1]], contour_line_level=2, contours=True, contour_lines=True)

# %%
plot_img_at_inds_one(dataset[2], [img_inds[1]], contour_line_level=2, contours=True, contour_lines=True)

# %% [markdown]
# global min barrier

# %%
plot_img_at_inds_one(dataset[2], [img_inds[1]], contour_line_level=2, contour_lower_border_lvl=40, contours=True, contour_lines=True)

# %%
picture_plot.plot_images([without_green], contour_line_level=2, contour_lower_border_lvl=40, contours=True, contour_lines=True, xlabels=dataset[2][1][img_inds[1]], ylabels=dataset[2][2][img_inds[1]])

# %% [markdown]
# one for all and all for one

# %%
plot_img_at_inds_one(dataset[2], [img_inds[1]], contour_line_level=2, contour_min_gauss=True, contour_lower_border_lvl=8, contours=True, contour_lines=True)

# %%
picture_plot.plot_images([without_green], contour_line_level=2, contour_min_gauss=True, contour_lower_border_lvl=8, contours=True, contour_lines=True, xlabels=dataset[2][1][img_inds[1]], ylabels=dataset[2][2][img_inds[1]])

# %%
plot_img_at_inds_one(dataset[2], [img_inds[1]], contour_line_level=2, contour_min_gauss=True, contour_lower_border_lvl=8, contours=True, contour_lines=True)

# %%
width = 3
height = 3
plt.rcParams['figure.figsize'] = [width, height]

# %%
plot_img_at_inds_one(dataset[2], [img_inds[1]], pie_charts=True, pie_num=25)

# %%
plot_img_at_inds_one(dataset[2], [img_inds[1]], pie_charts=True, pie_num=35)

# %%
plot_img_at_inds_one(dataset[2], [img_inds[1]], pie_charts=True, pie_num=40)

# %%
plot_img_at_inds_one(dataset[2], [img_inds[1]], pie_charts=True, pie_num=50)

# %%
plot_img_at_inds_one(dataset[2], [img_inds[1]], pie_charts=True, pie_num=66)

# %%
plot_img_at_inds_one(dataset[2], [img_inds[1]], pie_charts=True, pie_num=75)

# %%
plot_img_at_inds_one(dataset[2], [img_inds[1]], pie_charts=True, pie_num=100)
