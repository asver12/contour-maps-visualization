# %%
from matplotlib import pyplot as plt
# %matplotlib inline
import numpy as np
import itertools as it
import sys
sys.path.append("..")
from src import hierarchic_blending_operator
from src import color_converter
from src import color_operations
from src import color_schemes
from src import picture_worker
from src import helper

# %%
# For autotesting
# %load_ext autoreload
# %autoreload 2

# %%
width = 9.5
height = 9.5
plt.rcParams['figure.figsize'] = [width, height]

# %%
def generate_gaussians(gaussians):
    return [helper.get_gaussian(*gaussian)[2] for gaussian in gaussians]

# %%
size = 200

# %%
x_min, x_max = -10, 10
y_min, y_max = -10, 10
mu_x, mu_y = 0,0
variance_x, variance_y = 5,5
gaussian_static = [x_min, x_max, y_min, y_max, mu_x, variance_x, mu_y, variance_y, size]

# %%
colorschemes = color_schemes.get_colorbrewer_schemes()

# %%
color_codes = [color_schemes.get_main_color(i)[-1] for i in colorschemes]

# %%
static_gaussian_rep = [gaussian_static.copy(), gaussian_static.copy(), gaussian_static.copy(), gaussian_static.copy(), gaussian_static.copy()]

# %%
static_gaussian_rep = [gaussian_static.copy(), gaussian_static.copy(), gaussian_static.copy(), gaussian_static.copy(), gaussian_static.copy()]
images_overlapping = []
z_sums = []
gaussians = []
for i in range(1,len(static_gaussian_rep)+1):
    print(static_gaussian_rep[:i])
    z_list, image, z_sum = picture_worker.generate_image(static_gaussian_rep[:i], colorschemes, use_c_implementation=True, color_space="lab")
    images_overlapping.append(image)
    z_sums.append(z_sum)
    gaussians.append((static_gaussian_rep[:i]).copy())
# Out:
# [[-10, 10, -10, 10, 0, 5, 0, 5, 200]]
# [[-10, 10, -10, 10, 0, 5, 0, 5, 200], [-10, 10, -10, 10, 0, 5, 0, 5, 200]]
# [[-10, 10, -10, 10, 0, 5, 0, 5, 200], [-10, 10, -10, 10, 0, 5, 0, 5, 200], [-10, 10, -10, 10, 0, 5, 0, 5, 200]]
# [[-10, 10, -10, 10, 0, 5, 0, 5, 200], [-10, 10, -10, 10, 0, 5, 0, 5, 200], [-10, 10, -10, 10, 0, 5, 0, 5, 200], [-10, 10, -10, 10, 0, 5, 0, 5, 200]]
# [[-10, 10, -10, 10, 0, 5, 0, 5, 200], [-10, 10, -10, 10, 0, 5, 0, 5, 200], [-10, 10, -10, 10, 0, 5, 0, 5, 200], [-10, 10, -10, 10, 0, 5, 0, 5, 200], [-10, 10, -10, 10, 0, 5, 0, 5, 200]]

# %%
static_gaussian_rep = [gaussian_static.copy(), gaussian_static.copy(), gaussian_static.copy(), gaussian_static.copy(), gaussian_static.copy()]
for i in range(1,len(static_gaussian_rep)+1):
    if i != len(static_gaussian_rep)+1:
        static_gaussian_rep[i-1][5] += (i-1)/10
        static_gaussian_rep[i-1][7] += (i-1)/10
        print(static_gaussian_rep[i-1])
    z_list, image, z_sum = picture_worker.generate_image(static_gaussian_rep[:i], colorschemes, use_c_implementation=True, color_space="lab")
    images_overlapping.append(image)
    z_sums.append(z_sum)
    gaussians.append(static_gaussian_rep[:i].copy())
# Out:
# [-10, 10, -10, 10, 0, 5.0, 0, 5.0, 200]
# [-10, 10, -10, 10, 0, 5.1, 0, 5.1, 200]
# [-10, 10, -10, 10, 0, 5.2, 0, 5.2, 200]
# [-10, 10, -10, 10, 0, 5.3, 0, 5.3, 200]
# [-10, 10, -10, 10, 0, 5.4, 0, 5.4, 200]

# %%
static_gaussian_rep = [gaussian_static.copy(), gaussian_static.copy(), gaussian_static.copy(), gaussian_static.copy(), gaussian_static.copy()]
for i in range(1,len(static_gaussian_rep)+1):
    if i != len(static_gaussian_rep)+1:
        static_gaussian_rep[i-1][5] += (i-1)
        static_gaussian_rep[i-1][7] += (i-1)
        print(static_gaussian_rep[i-1])
    z_list, image, z_sum = picture_worker.generate_image(static_gaussian_rep[:i], colorschemes, use_c_implementation=True, color_space="lab")
    images_overlapping.append(image)
    z_sums.append(z_sum)
    gaussians.append(static_gaussian_rep[:i].copy())
# Out:
# [-10, 10, -10, 10, 0, 5, 0, 5, 200]
# [-10, 10, -10, 10, 0, 6, 0, 6, 200]
# [-10, 10, -10, 10, 0, 7, 0, 7, 200]
# [-10, 10, -10, 10, 0, 8, 0, 8, 200]
# [-10, 10, -10, 10, 0, 9, 0, 9, 200]

# %%
static_gaussian_rep = [gaussian_static.copy(), gaussian_static.copy(), gaussian_static.copy(), gaussian_static.copy(), gaussian_static.copy()]
for i in range(1,len(static_gaussian_rep)+1):
    if i != len(static_gaussian_rep)+1:
        static_gaussian_rep[i-1][5] += (i-1)*10
        static_gaussian_rep[i-1][7] += (i-1)*10
        print(static_gaussian_rep[i-1])
    z_list, image, z_sum = picture_worker.generate_image(static_gaussian_rep[:i], colorschemes, use_c_implementation=True, color_space="lab")
    images_overlapping.append(image)
    z_sums.append(z_sum)
    gaussians.append(static_gaussian_rep[:i].copy())
# Out:
# [-10, 10, -10, 10, 0, 5, 0, 5, 200]
# [-10, 10, -10, 10, 0, 15, 0, 15, 200]
# [-10, 10, -10, 10, 0, 25, 0, 25, 200]
# [-10, 10, -10, 10, 0, 35, 0, 35, 200]
# [-10, 10, -10, 10, 0, 45, 0, 45, 200]

# %%
static_gaussian_rep = [gaussian_static.copy(), gaussian_static.copy(), gaussian_static.copy(), gaussian_static.copy(), gaussian_static.copy()]
images_overlapping = []
z_sums = []
gaussians = []
for i in range(1,len(static_gaussian_rep)+1):
    print(static_gaussian_rep[:i])
    z_list, image, z_sum = picture_worker.generate_image(static_gaussian_rep[:i], colorschemes, use_c_implementation=True, color_space="lab")
    images_overlapping.append(image)
    z_sums.append(z_sum)
    gaussians.append((static_gaussian_rep[:i]).copy())
# Out:
# [[-10, 10, -10, 10, 0, 5, 0, 5, 200]]
# [[-10, 10, -10, 10, 0, 5, 0, 5, 200], [-10, 10, -10, 10, 0, 5, 0, 5, 200]]
# [[-10, 10, -10, 10, 0, 5, 0, 5, 200], [-10, 10, -10, 10, 0, 5, 0, 5, 200], [-10, 10, -10, 10, 0, 5, 0, 5, 200]]
# [[-10, 10, -10, 10, 0, 5, 0, 5, 200], [-10, 10, -10, 10, 0, 5, 0, 5, 200], [-10, 10, -10, 10, 0, 5, 0, 5, 200], [-10, 10, -10, 10, 0, 5, 0, 5, 200]]
# [[-10, 10, -10, 10, 0, 5, 0, 5, 200], [-10, 10, -10, 10, 0, 5, 0, 5, 200], [-10, 10, -10, 10, 0, 5, 0, 5, 200], [-10, 10, -10, 10, 0, 5, 0, 5, 200], [-10, 10, -10, 10, 0, 5, 0, 5, 200]]

# %%
static_gaussian_rep = [gaussian_static.copy(), gaussian_static.copy(), gaussian_static.copy(), gaussian_static.copy(), gaussian_static.copy()]
for i in range(1,len(static_gaussian_rep)+1):
    if i != len(static_gaussian_rep)+1:
        static_gaussian_rep[i-1][5] += round(((i-1)/10)**2,2)
        static_gaussian_rep[i-1][7] += round(((i-1)/10)**2,2)
        print(static_gaussian_rep[i-1])
    z_list, image, z_sum = picture_worker.generate_image(static_gaussian_rep[:i], colorschemes, use_c_implementation=True, color_space="lab")
    images_overlapping.append(image)
    z_sums.append(z_sum)
    gaussians.append(static_gaussian_rep[:i].copy())
# Out:
# [-10, 10, -10, 10, 0, 5.0, 0, 5.0, 200]
# [-10, 10, -10, 10, 0, 5.01, 0, 5.01, 200]
# [-10, 10, -10, 10, 0, 5.04, 0, 5.04, 200]
# [-10, 10, -10, 10, 0, 5.09, 0, 5.09, 200]
# [-10, 10, -10, 10, 0, 5.16, 0, 5.16, 200]

# %%
static_gaussian_rep = [gaussian_static.copy(), gaussian_static.copy(), gaussian_static.copy(), gaussian_static.copy(), gaussian_static.copy()]
for i in range(1,len(static_gaussian_rep)+1):
    if i != len(static_gaussian_rep)+1:
        static_gaussian_rep[i-1][5] = round(static_gaussian_rep[i-1][5] + (4*(i-1)/10)**2,2)
        static_gaussian_rep[i-1][7] = round(static_gaussian_rep[i-1][7] + (4*(i-1)/10)**2,2)
        print(static_gaussian_rep[i-1])
    z_list, image, z_sum = picture_worker.generate_image(static_gaussian_rep[:i], colorschemes, use_c_implementation=True, color_space="lab")
    images_overlapping.append(image)
    z_sums.append(z_sum)
    gaussians.append(static_gaussian_rep[:i].copy())
# Out:
# [-10, 10, -10, 10, 0, 5.0, 0, 5.0, 200]
# [-10, 10, -10, 10, 0, 5.16, 0, 5.16, 200]
# [-10, 10, -10, 10, 0, 5.64, 0, 5.64, 200]
# [-10, 10, -10, 10, 0, 6.44, 0, 6.44, 200]
# [-10, 10, -10, 10, 0, 7.56, 0, 7.56, 200]

# %%
static_gaussian_rep = [gaussian_static.copy(), gaussian_static.copy(), gaussian_static.copy(), gaussian_static.copy(), gaussian_static.copy()]
for i in range(1,len(static_gaussian_rep)+1):
    if i != len(static_gaussian_rep)+1:
        static_gaussian_rep[i-1][5] += round((i-1)**2,2)
        static_gaussian_rep[i-1][7] += round((i-1)**2,2)
        print(static_gaussian_rep[i-1])
    z_list, image, z_sum = picture_worker.generate_image(static_gaussian_rep[:i], colorschemes, use_c_implementation=True, color_space="lab")
    images_overlapping.append(image)
    z_sums.append(z_sum)
    gaussians.append(static_gaussian_rep[:i].copy())
# Out:
# [-10, 10, -10, 10, 0, 5, 0, 5, 200]
# [-10, 10, -10, 10, 0, 6, 0, 6, 200]
# [-10, 10, -10, 10, 0, 9, 0, 9, 200]
# [-10, 10, -10, 10, 0, 14, 0, 14, 200]
# [-10, 10, -10, 10, 0, 21, 0, 21, 200]

# %%
static_gaussian_rep = [gaussian_static.copy(), gaussian_static.copy(), gaussian_static.copy(), gaussian_static.copy(), gaussian_static.copy()]
for i in range(1,len(static_gaussian_rep)+1):
    if i != len(static_gaussian_rep)+1:
        static_gaussian_rep[i-1][5] += round(2*(i-1)**2,2)
        static_gaussian_rep[i-1][7] += round(2*(i-1)**2,2)
        print(static_gaussian_rep[i-1])
    z_list, image, z_sum = picture_worker.generate_image(static_gaussian_rep[:i], colorschemes, use_c_implementation=True, color_space="lab")
    images_overlapping.append(image)
    z_sums.append(z_sum)
    gaussians.append(static_gaussian_rep[:i].copy())
# Out:
# [-10, 10, -10, 10, 0, 5, 0, 5, 200]
# [-10, 10, -10, 10, 0, 7, 0, 7, 200]
# [-10, 10, -10, 10, 0, 13, 0, 13, 200]
# [-10, 10, -10, 10, 0, 23, 0, 23, 200]
# [-10, 10, -10, 10, 0, 37, 0, 37, 200]

# %% [markdown]
# Reihe: Erklärung <br>
# 1: Beispielreihe <br>
# 2: Varianz in X und Y-Richtung verändert sich immer um genau 0.1 pro hinzugefügten Gaussian <br>
# 3: Varianz in X und Y-Richtung verändert sich immer um genau 1 pro hinzugefügten Gaussian <br>
# 4: Varianz in X und Y-Richtung verändert sich immer um genau 10 pro hinzugefügten Gaussian <br>

# %%
picture_worker.plot_images(images_overlapping, gaussians, z_sums, color_codes)
# Out:
# ['mu_x', 'variance_x', 'mu_y', 'variance_y']

# %% [markdown]
# Reihe: Erklärung <br>
# 1: Beispielreihe <br>
# 2: Varianz in X und Y-Richtung verändert sich immer exponential um (i/10)^2 pro hinzugefügten Gaussian <br>
# 3: Varianz in X und Y-Richtung verändert sich immer exponential um (4*i/10)^2 pro hinzugefügten Gaussian <br>
# 4: Varianz in X und Y-Richtung verändert sich immer exponential um i^2 pro hinzugefügten Gaussian <br>
# 5: Varianz in X und Y-Richtung verändert sich immer exponential um 2*i^2 pro hinzugefügten Gaussian <br>

# %%
picture_worker.plot_images(images_overlapping, gaussians, z_sums, color_codes)
# Out:
# ['mu_x', 'variance_x', 'mu_y', 'variance_y']
