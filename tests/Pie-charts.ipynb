# %%
import matplotlib.pyplot as plt
import numpy as np
import math

from contour_visualization import helper
from contour_visualization import example_data
from contour_visualization import color_schemes
from contour_visualization import picture_contours
from contour_visualization import pie_chart_vis
from contour_visualization import picture_plot

# %%
# %load_ext autoreload
# %autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
width = 9.5
height = 9.5
plt.rcParams['figure.figsize'] = [width, height]

# %%
colorschemes = color_schemes.get_colorbrewer_schemes()
color_codes = [color_schemes.get_main_color(i)[-1] for i in colorschemes]

# %%
z_lists, z_sums, gaussians, color_codes = example_data.generate_four_moving_gaussians(size=100)
# Out:
# 10:06:21.436 INFO :: [-10, 10, -10, 10, [1, 1], [[5, 0], [0, 5]], 1, 100]
#  [-10, 10, -10, 10, [-1, -1], [[5, 0], [0, 5]], 1, 100]
#  [-10, 10, -10, 10, [1, -1], [[5, 0], [0, 5]], 1, 100]
#  [-10, 10, -10, 10, [-1, 1], [[5, 0], [0, 5]], 1, 100]
# 10:06:21.443 INFO :: [-10, 10, -10, 10, [2, 2], [[5, 0], [0, 5]], 1, 100]
#  [-10, 10, -10, 10, [-2, -2], [[5, 0], [0, 5]], 1, 100]
#  [-10, 10, -10, 10, [2, -2], [[5, 0], [0, 5]], 1, 100]
#  [-10, 10, -10, 10, [-2, 2], [[5, 0], [0, 5]], 1, 100]
# 10:06:21.449 INFO :: [-10, 10, -10, 10, [3, 3], [[5, 0], [0, 5]], 1, 100]
#  [-10, 10, -10, 10, [-3, -3], [[5, 0], [0, 5]], 1, 100]
#  [-10, 10, -10, 10, [3, -3], [[5, 0], [0, 5]], 1, 100]
#  [-10, 10, -10, 10, [-3, 3], [[5, 0], [0, 5]], 1, 100]
# 10:06:21.454 INFO :: [-10, 10, -10, 10, [4, 4], [[5, 0], [0, 5]], 1, 100]
#  [-10, 10, -10, 10, [-4, -4], [[5, 0], [0, 5]], 1, 100]
#  [-10, 10, -10, 10, [4, -4], [[5, 0], [0, 5]], 1, 100]
#  [-10, 10, -10, 10, [-4, 4], [[5, 0], [0, 5]], 1, 100]
# 10:06:21.460 INFO :: [-10, 10, -10, 10, [5, 5], [[5, 0], [0, 5]], 1, 100]
#  [-10, 10, -10, 10, [-5, -5], [[5, 0], [0, 5]], 1, 100]
#  [-10, 10, -10, 10, [5, -5], [[5, 0], [0, 5]], 1, 100]
#  [-10, 10, -10, 10, [-5, 5], [[5, 0], [0, 5]], 1, 100]

# %%
fig, ax = plt.subplots(1,1)
pie_chart_vis.draw_pie(ax, [0.00816257, 0.00816257, 1.,         0.        ], (0.5,0.5), radius=0.4)

# %%
picture_plot.plot_images(gaussians, contours=True, contour_lines=True, contour_line_level = 2)

# %%
fig, axis = plt.subplots(1,1)
picture_plot.plot_image(axis, gaussians[3] , pie_charts=True, contour_lines=True, pie_num = 20, pie_angle=90, pie_chart_iso_level=40, pie_chart_modus="both")

# %%
fig, axis = plt.subplots(1,1)
picture_plot.plot_image(axis, gaussians[3], contour_lines=True, contours=False, pie_charts=False, pie_num=25, pie_chart_modus = "light", crosses=True)

# %%
fig, axis = plt.subplots(1,1)
picture_plot.plot_image(axis, gaussians[0], contour_lines=True, contours=False, pie_charts=True, pie_num=25, pie_chart_modus = "both", crosses=False)
# Out:
# 10:06:27.251 WARNING :: Input [0.10424403713096865] bigger than Max-Value [0.10407399609104848] found
# 10:06:27.251 WARNING :: Input [0.10424403713096865] bigger than Max-Value [0.10407399609104848] found
# 10:06:27.252 WARNING :: Input [0.10424403713096865] bigger than Max-Value [0.10407399609104848] found
# 10:06:27.252 WARNING :: Input [0.10424403713096865] bigger than Max-Value [0.10407399609104848] found
# 10:06:27.253 WARNING :: Input [0.10424403713096865] bigger than Max-Value [0.10407399609104848] found

# %%
fig, axis = plt.subplots(1,1)
picture_plot.plot_image(axis, gaussians[0], contour_lines=True, contours=False, pie_charts=True, pie_num=25,crosses=False)
# Out:
# 10:06:28.553 WARNING :: Input [0.10424403713096865] bigger than Max-Value [0.10407399609104848] found
# 10:06:28.554 WARNING :: Input [0.10424403713096865] bigger than Max-Value [0.10407399609104848] found
# 10:06:28.555 WARNING :: Input [0.10424403713096865] bigger than Max-Value [0.10407399609104848] found
# 10:06:28.556 WARNING :: Input [0.10424403713096865] bigger than Max-Value [0.10407399609104848] found
# 10:06:28.556 WARNING :: Input [0.10424403713096865] bigger than Max-Value [0.10407399609104848] found

# %%
picture_plot.plot_images(gaussians, pie_charts= True)
# Out:
# 10:06:30.180 WARNING :: Input [0.03183387893328272] bigger than Max-Value [0.03181795001352063] found
# 10:06:30.181 WARNING :: Input [0.03183387893328272] bigger than Max-Value [0.03181795001352063] found
# 10:06:30.181 WARNING :: Input [0.03183387893328272] bigger than Max-Value [0.03181795001352063] found
# 10:06:30.182 WARNING :: Input [0.03183387893328272] bigger than Max-Value [0.03181795001352063] found
# 10:06:30.183 WARNING :: Input [0.03183387893328272] bigger than Max-Value [0.03181795001352063] found
# 10:06:30.196 WARNING :: Input [0.03183387893328272] bigger than Max-Value [0.03181795001352063] found
# 10:06:30.197 WARNING :: Input [0.03183387893328272] bigger than Max-Value [0.03181795001352063] found
# 10:06:30.198 WARNING :: Input [0.03183387893328272] bigger than Max-Value [0.03181795001352063] found
# 10:06:30.198 WARNING :: Input [0.03183387893328272] bigger than Max-Value [0.03181795001352063] found
# 10:06:30.199 WARNING :: Input [0.03183387893328272] bigger than Max-Value [0.03181795001352063] found
# 10:06:30.281 WARNING :: Input [0.03183387893328272] bigger than Max-Value [0.03181795001352063] found
# 10:06:30.282 WARNING :: Input [0.03183387893328272] bigger than Max-Value [0.03181795001352063] found
# 10:06:30.282 WARNING :: Input [0.03183387893328272] bigger than Max-Value [0.03181795001352063] found
# 10:06:30.283 WARNING :: Input [0.03183387893328272] bigger than Max-Value [0.03181795001352063] found
# 10:06:30.284 WARNING :: Input [0.03183387893328272] bigger than Max-Value [0.03181795001352063] found
# 10:06:30.296 WARNING :: Input [0.03183387893328272] bigger than Max-Value [0.03181795001352063] found
# 10:06:30.296 WARNING :: Input [0.03183387893328272] bigger than Max-Value [0.03181795001352063] found
# 10:06:30.297 WARNING :: Input [0.03183387893328272] bigger than Max-Value [0.03181795001352063] found
# 10:06:30.298 WARNING :: Input [0.03183387893328272] bigger than Max-Value [0.03181795001352063] found
# 10:06:30.298 WARNING :: Input [0.03183387893328272] bigger than Max-Value [0.03181795001352063] found

# %%
picture_plot.plot_images(gaussians, pie_charts= True, pie_chart_modus="size")

# %%
picture_plot.plot_images(gaussians, contour_lines=True, pie_charts= True,  crosses=True)
# Out:
# 10:06:35.581 WARNING :: Input [0.03183387893328272] bigger than Max-Value [0.03181795001352063] found
# 10:06:35.582 WARNING :: Input [0.03183387893328272] bigger than Max-Value [0.03181795001352063] found
# 10:06:35.582 WARNING :: Input [0.03183387893328272] bigger than Max-Value [0.03181795001352063] found
# 10:06:35.583 WARNING :: Input [0.03183387893328272] bigger than Max-Value [0.03181795001352063] found
# 10:06:35.584 WARNING :: Input [0.03183387893328272] bigger than Max-Value [0.03181795001352063] found
# 10:06:35.595 WARNING :: Input [0.03183387893328272] bigger than Max-Value [0.03181795001352063] found
# 10:06:35.596 WARNING :: Input [0.03183387893328272] bigger than Max-Value [0.03181795001352063] found
# 10:06:35.597 WARNING :: Input [0.03183387893328272] bigger than Max-Value [0.03181795001352063] found
# 10:06:35.597 WARNING :: Input [0.03183387893328272] bigger than Max-Value [0.03181795001352063] found
# 10:06:35.598 WARNING :: Input [0.03183387893328272] bigger than Max-Value [0.03181795001352063] found
# 10:06:35.679 WARNING :: Input [0.03183387893328272] bigger than Max-Value [0.03181795001352063] found
# 10:06:35.680 WARNING :: Input [0.03183387893328272] bigger than Max-Value [0.03181795001352063] found
# 10:06:35.681 WARNING :: Input [0.03183387893328272] bigger than Max-Value [0.03181795001352063] found
# 10:06:35.681 WARNING :: Input [0.03183387893328272] bigger than Max-Value [0.03181795001352063] found
# 10:06:35.682 WARNING :: Input [0.03183387893328272] bigger than Max-Value [0.03181795001352063] found
# 10:06:35.693 WARNING :: Input [0.03183387893328272] bigger than Max-Value [0.03181795001352063] found
# 10:06:35.694 WARNING :: Input [0.03183387893328272] bigger than Max-Value [0.03181795001352063] found
# 10:06:35.694 WARNING :: Input [0.03183387893328272] bigger than Max-Value [0.03181795001352063] found
# 10:06:35.695 WARNING :: Input [0.03183387893328272] bigger than Max-Value [0.03181795001352063] found
# 10:06:35.695 WARNING :: Input [0.03183387893328272] bigger than Max-Value [0.03181795001352063] found
