# %%
import matplotlib.pyplot as plt
import numpy as np
import math

import sys
sys.path.append("..")
from src import helper
from src import example_data
from src import color_schemes
from src import picture_worker
from src import pie_chart_vis
from src import picture_plot

# %%
# %load_ext autoreload
# %autoreload

# %%
width = 9.5
height = 9.5
plt.rcParams['figure.figsize'] = [width, height]

# %%
colorschemes = color_schemes.get_colorbrewer_schemes()
color_codes = [color_schemes.get_main_color(i)[-1] for i in colorschemes]

# %%
z_lists, z_sums, gaussians, color_codes = example_data.generate_four_moving_gaussians(size=100)
# Out:
# [-10, 10, -10, 10, [1, 1], [[5, 0], [0, 5]], 1, 100]
#  [-10, 10, -10, 10, [-1, -1], [[5, 0], [0, 5]], 1, 100]
#  [-10, 10, -10, 10, [1, -1], [[5, 0], [0, 5]], 1, 100]
#  [-10, 10, -10, 10, [-1, 1], [[5, 0], [0, 5]], 1, 100]
# [-10, 10, -10, 10, [2, 2], [[5, 0], [0, 5]], 1, 100]
#  [-10, 10, -10, 10, [-2, -2], [[5, 0], [0, 5]], 1, 100]
#  [-10, 10, -10, 10, [2, -2], [[5, 0], [0, 5]], 1, 100]
#  [-10, 10, -10, 10, [-2, 2], [[5, 0], [0, 5]], 1, 100]
# [-10, 10, -10, 10, [3, 3], [[5, 0], [0, 5]], 1, 100]
#  [-10, 10, -10, 10, [-3, -3], [[5, 0], [0, 5]], 1, 100]
#  [-10, 10, -10, 10, [3, -3], [[5, 0], [0, 5]], 1, 100]
#  [-10, 10, -10, 10, [-3, 3], [[5, 0], [0, 5]], 1, 100]
# [-10, 10, -10, 10, [4, 4], [[5, 0], [0, 5]], 1, 100]
#  [-10, 10, -10, 10, [-4, -4], [[5, 0], [0, 5]], 1, 100]
#  [-10, 10, -10, 10, [4, -4], [[5, 0], [0, 5]], 1, 100]
#  [-10, 10, -10, 10, [-4, 4], [[5, 0], [0, 5]], 1, 100]
# [-10, 10, -10, 10, [5, 5], [[5, 0], [0, 5]], 1, 100]
# ...

# %%
fig, ax = plt.subplots(1,1)
pie_chart_vis.draw_pie(ax, [0.00816257, 0.00816257, 1.,         0.        ], (0.5,0.5), radius=0.4)

# %%
picture_plot.plot_images(gaussians, contours=True, contour_lines=True, contour_line_level = 2)

# %%
fig, axis = plt.subplots(1,1)
picture_plot.plot_image(axis, gaussians[3] , pie_charts=True, contour_lines=True, num_of_pies = 10, angle=90, pie_chart_modus="both")
# Out:
# Level: [0.00605195 0.00967686 0.01240381 0.01447021 0.01702484 0.01988028
#  0.02283862 0.0258588  0.02882353]
# (100, 100)

# %%
fig, axis = plt.subplots(1,1)
picture_plot.plot_image(axis, gaussians[3], contour_lines=True, contours=False, pie_charts=True, num_of_pies=25, pie_chart_modus = "light", crosses=False)
# Out:
# Level: [0.00605195 0.00967686 0.01240381 0.01447021 0.01702484 0.01988028
#  0.02283862 0.0258588  0.02882353]
# (100, 100)
# Input [0.03193685451780175] bigger than Max-Value [0.031924183657143994] found
# Input [0.03193685451780175] bigger than Max-Value [0.031924183657143994] found
# Input [0.03193685451780175] bigger than Max-Value [0.031924183657143994] found
# Input [0.03193685451780175] bigger than Max-Value [0.031924183657143994] found
# Input [0.03193685451780175] bigger than Max-Value [0.031924183657143994] found
# Input [0.031936854517801753] bigger than Max-Value [0.031924183657143994] found
# Input [0.031936854517801753] bigger than Max-Value [0.031924183657143994] found
# Input [0.031936854517801753] bigger than Max-Value [0.031924183657143994] found
# Input [0.031936854517801753] bigger than Max-Value [0.031924183657143994] found
# Input [0.031936854517801753] bigger than Max-Value [0.031924183657143994] found
# ...

# %%
fig, axis = plt.subplots(1,1)
picture_plot.plot_image(axis, gaussians[0], contour_lines=True, contours=False, pie_charts=True, num_of_pies=25, pie_chart_modus = "both", crosses=False)
# Out:
# Level: [0.01085822 0.0214236  0.03202681 0.04232483 0.05321015 0.06312151
#  0.07253898 0.08329303 0.09373762]
# (100, 100)
# Input [0.10424403713096865] bigger than Max-Value [0.10407399609104848] found
# Input [0.10424403713096865] bigger than Max-Value [0.10407399609104848] found
# Input [0.10424403713096865] bigger than Max-Value [0.10407399609104848] found
# Input [0.10424403713096865] bigger than Max-Value [0.10407399609104848] found
# Input [0.10424403713096865] bigger than Max-Value [0.10407399609104848] found

# %%
fig, axis = plt.subplots(1,1)
picture_plot.plot_image(axis, gaussians[0], contour_lines=True, contours=False, pie_charts=True, num_of_pies=25,crosses=False)
# Out:
# Level: [0.01085822 0.0214236  0.03202681 0.04232483 0.05321015 0.06312151
#  0.07253898 0.08329303 0.09373762]
# (100, 100)
# Input [0.10424403713096865] bigger than Max-Value [0.10407399609104848] found
# Input [0.10424403713096865] bigger than Max-Value [0.10407399609104848] found
# Input [0.10424403713096865] bigger than Max-Value [0.10407399609104848] found
# Input [0.10424403713096865] bigger than Max-Value [0.10407399609104848] found
# Input [0.10424403713096865] bigger than Max-Value [0.10407399609104848] found

# %%
picture_plot.plot_images(gaussians, pie_charts= True)
# Out:
# Input [0.03183387893328272] bigger than Max-Value [0.03181795001352063] found
# Input [0.03183387893328272] bigger than Max-Value [0.03181795001352063] found
# Input [0.03183387893328272] bigger than Max-Value [0.03181795001352063] found
# Input [0.03183387893328272] bigger than Max-Value [0.03181795001352063] found
# Input [0.03183387893328272] bigger than Max-Value [0.03181795001352063] found
# Input [0.03183387893328272] bigger than Max-Value [0.03181795001352063] found
# Input [0.03183387893328272] bigger than Max-Value [0.03181795001352063] found
# Input [0.03183387893328272] bigger than Max-Value [0.03181795001352063] found
# Input [0.03183387893328272] bigger than Max-Value [0.03181795001352063] found
# Input [0.03183387893328272] bigger than Max-Value [0.03181795001352063] found
# Input [0.03183387893328272] bigger than Max-Value [0.03181795001352063] found
# Input [0.03183387893328272] bigger than Max-Value [0.03181795001352063] found
# ...

# %%
picture_plot.plot_images(gaussians, pie_charts= True, pie_chart_modus="size")

# %%
picture_plot.plot_images(gaussians,contour_lines=True, pie_charts= True,  crosses=True)
# Out:
# Level: [0.01085822 0.0214236  0.03202681 0.04232483 0.05321015 0.06312151
#  0.07253898 0.08329303 0.09373762]
# (100, 100)
# Level: [0.00859741 0.01604495 0.02290875 0.0298598  0.03551839 0.04100487
#  0.0461826  0.05036739 0.05409646]
# (100, 100)
# Level: [0.00708737 0.01307776 0.01808028 0.02194118 0.02428282 0.02623756
#  0.02753192 0.02922603 0.03136629]
# (100, 100)
# Level: [0.00605195 0.00967686 0.01240381 0.01447021 0.01702484 0.01988028
#  0.02283862 0.0258588  0.02882353]
# (100, 100)
# Input [0.03183387893328272] bigger than Max-Value [0.03181795001352063] found
# Input [0.03183387893328272] bigger than Max-Value [0.03181795001352063] found
# Input [0.03183387893328272] bigger than Max-Value [0.03181795001352063] found
# Input [0.03183387893328272] bigger than Max-Value [0.03181795001352063] found
# Input [0.03183387893328272] bigger than Max-Value [0.03181795001352063] found
# Input [0.03183387893328272] bigger than Max-Value [0.03181795001352063] found
# ...
