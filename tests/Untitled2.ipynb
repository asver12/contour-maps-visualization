# %%
import numpy as np
import pickle
import os
import sys
sys.path.append("..")
from src import picture_plot
from src import scatterplot_matrix
from src.ModelbaseDistribution import ModelbaseDistribution
import matplotlib.pyplot as plt

# %%
# %load_ext autoreload
# %autoreload

# %%
width = 19
height = 19
plt.rcParams['figure.figsize'] = [width, height]

# %%
model_test = pickle.load(open("../../fitted_models/mcg_iris_map.mdl", "rb"))
# Out:
# 11:41:09.110 WARNING :: Using NumPy C-API based implementation for BLAS functions.

# %%
fig = scatterplot_matrix.scatterplot_matrix(model_test, "species", ["sepal_length", "sepal_width", "petal_length", "petal_width"], contour_lines=True, contours=True, size=50)
# Out:
# 11:41:09.704 INFO :: x: 0 , y: 1
# 11:41:09.717 INFO :: [x_min: -1.4600000000000002, x_max: 9.46, y_min: -1.4600000000000002, y_max: 9.46, weight: 1, size: 50]
# 11:41:09.744 INFO :: [x_min: -1.4600000000000002, x_max: 9.46, y_min: -1.4600000000000002, y_max: 9.46, weight: 1, size: 50]
# 11:41:09.770 INFO :: [x_min: -1.4600000000000002, x_max: 9.46, y_min: -1.4600000000000002, y_max: 9.46, weight: 1, size: 50]
# 11:41:29.110 INFO :: x: 0 , y: 2
# 11:41:29.123 INFO :: [x_min: -1.4600000000000002, x_max: 9.46, y_min: -1.4600000000000002, y_max: 9.46, weight: 1, size: 50]
# 11:41:29.145 INFO :: [x_min: -1.4600000000000002, x_max: 9.46, y_min: -1.4600000000000002, y_max: 9.46, weight: 1, size: 50]
# 11:41:29.166 INFO :: [x_min: -1.4600000000000002, x_max: 9.46, y_min: -1.4600000000000002, y_max: 9.46, weight: 1, size: 50]
# 11:41:46.322 INFO :: x: 0 , y: 3
# 11:41:46.334 INFO :: [x_min: -1.4600000000000002, x_max: 9.46, y_min: -1.4600000000000002, y_max: 9.46, weight: 1, size: 50]
# ...
