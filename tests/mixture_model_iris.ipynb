# %%
from contour_visualization import picture_plot, MixtureModel

# %%
import pickle
import matplotlib.pyplot as plt

# %%
import logging
logger = logging.getLogger("contour_visualization.picture_plot")
logger.setLevel(logging.DEBUG)

# %%
# %load_ext autoreload
# %autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
width = 9.5
height = 9.5
plt.rcParams['figure.figsize'] = [width, height]

# %%
model_test = pickle.load(open("../../fitted_models/mcg_iris_map.mdl", "rb"))

# %%
model_test.data.columns
# Out:
# Index(['species', 'sepal_length', 'sepal_width', 'petal_length',
#        'petal_width'],
#       dtype='object')

# %%
model_1 = MixtureModel.MixtureModel(model_test.data[["sepal_length", "sepal_width"]])

# %%
model_2 = MixtureModel.MixtureModel(model_test.data[["sepal_length", "petal_length"]])

# %%
model_3 = MixtureModel.MixtureModel(model_test.data[["sepal_length", "petal_width"]])

# %%
model_4 = MixtureModel.MixtureModel(model_test.data[["sepal_width", "petal_length"]])

# %%
model_5 = MixtureModel.MixtureModel(model_test.data[["sepal_width", "petal_width"]])

# %%
model_6 = MixtureModel.MixtureModel(model_test.data[["petal_length", "petal_width"]])

# %%
models = [model_1.get_gaussians(), model_2.get_gaussians(), model_3.get_gaussians(), model_4.get_gaussians(), model_5.get_gaussians(), model_6.get_gaussians()]
# Out:
# 10:20:09.518 INFO :: Means[0]: [4.98537147 3.45559252]
# 10:20:09.520 INFO :: Cov-Matrix[0]: [[0.11399981 0.09103105]
#  [0.09103105 0.1208071 ]]
# 10:20:09.520 INFO :: weights[0]: 0.316084148177187
# 10:20:09.521 INFO :: Means[1]: [6.65182243 3.037754  ]
# 10:20:09.522 INFO :: Cov-Matrix[1]: [[0.35227063 0.06827917]
#  [0.06827917 0.08722759]]
# 10:20:09.522 INFO :: weights[1]: 0.31351712141279775
# 10:20:09.523 INFO :: Means[2]: [5.86415676 2.7352466 ]
# 10:20:09.523 INFO :: Cov-Matrix[2]: [[0.28480826 0.0946101 ]
#  [0.0946101  0.09580995]]
# 10:20:09.524 INFO :: weights[2]: 0.3703987304100152
# 10:20:09.525 INFO :: Means[0]: [4.97500081 1.45908862]
# 10:20:09.525 INFO :: Cov-Matrix[0]: [[0.11596736 0.01556861]
#  [0.01556861 0.03150842]]
# 10:20:09.526 INFO :: weights[0]: 0.3259242202003243
# 10:20:09.526 INFO :: Means[1]: [6.00821904 4.41398863]
# 10:20:09.527 INFO :: Cov-Matrix[1]: [[0.28204142 0.23238634]
#  [0.23238634 0.32143389]]
# 10:20:09.527 INFO :: weights[1]: 0.3951954003670398
# 10:20:09.528 INFO :: Means[2]: [6.58862967 5.63119589]
# 10:20:09.529 INFO :: Cov-Matrix[2]: [[0.46282295 0.33019861]
#  [0.33019861 0.27789412]]
# 10:20:09.529 INFO :: weights[2]: 0.2788803794326358
# 10:20:09.530 INFO :: Means[0]: [4.97424985 0.23942576]
# 10:20:09.530 INFO :: Cov-Matrix[0]: [[0.1187092  0.00864992]
#  [0.00864992 0.0079803 ]]
# 10:20:09.531 INFO :: weights[0]: 0.31827394669711434
# 10:20:09.532 INFO :: Means[1]: [6.53814897 2.00764083]
# 10:20:09.532 INFO :: Cov-Matrix[1]: [[0.40585873 0.04826709]
#  [0.04826709 0.08193748]]
# 10:20:09.532 INFO :: weights[1]: 0.3455169918693259
# 10:20:09.533 INFO :: Means[2]: [5.92226048 1.31898983]
# 10:20:09.534 INFO :: Cov-Matrix[2]: [[0.30464385 0.09028205]
#  [0.09028205 0.05995515]]
# 10:20:09.534 INFO :: weights[2]: 0.3362090614335597
# 10:20:09.534 INFO :: Means[0]: [3.42727284 1.45909093]
# 10:20:09.535 INFO :: Cov-Matrix[0]: [[0.14698436 0.01066114]
#  [0.01066114 0.03150927]]
# 10:20:09.535 INFO :: weights[0]: 0.32592589272800815
# 10:20:09.536 INFO :: Means[1]: [2.81583524 4.4684791 ]
# 10:20:09.537 INFO :: Cov-Matrix[1]: [[0.09755288 0.11658242]
#  [0.11658242 0.35753463]]
# 10:20:09.537 INFO :: weights[1]: 0.4221768089349314
# 10:20:09.538 INFO :: Means[2]: [2.98518676 5.67027364]
# 10:20:09.539 INFO :: Cov-Matrix[2]: [[0.11938061 0.09304763]
#  [0.09304763 0.26975873]]
# 10:20:09.539 INFO :: weights[2]: 0.25189729833706054
# 10:20:09.540 INFO :: Means[0]: [3.42727274 0.24772727]
# 10:20:09.541 INFO :: Cov-Matrix[0]: [[0.14698446 0.00710744]
#  [0.00710744 0.01067765]]
# 10:20:09.541 INFO :: weights[0]: 0.32592592366131784
# 10:20:09.542 INFO :: Means[1]: [2.94753252 1.99195403]
# 10:20:09.543 INFO :: Cov-Matrix[1]: [[0.10130987 0.05910809]
#  [0.05910809 0.0847232 ]]
# 10:20:09.543 INFO :: weights[1]: 0.3615128329891796
# 10:20:09.544 INFO :: Means[2]: [2.79999499 1.31966345]
# 10:20:09.545 INFO :: Cov-Matrix[2]: [[0.11360085 0.05860929]
#  [0.05860929 0.04458837]]
# 10:20:09.545 INFO :: weights[2]: 0.3125612433495025
# 10:20:09.546 INFO :: Means[0]: [1.45908947 0.24772697]
# 10:20:09.547 INFO :: Cov-Matrix[0]: [[0.03150875 0.00604329]
#  [0.00604329 0.01067762]]
# 10:20:09.548 INFO :: weights[0]: 0.3259248081788392
# 10:20:09.554 INFO :: Means[1]: [4.33454169 1.37140143]
# 10:20:09.555 INFO :: Cov-Matrix[1]: [[0.26217894 0.10353727]
#  [0.10353727 0.05827643]]
# 10:20:09.556 INFO :: weights[1]: 0.3662521257114117
# 10:20:09.557 INFO :: Means[2]: [5.61128127 2.04765122]
# 10:20:09.557 INFO :: Cov-Matrix[2]: [[0.25374803 0.0312416 ]
#  [0.0312416  0.0730964 ]]
# 10:20:09.558 INFO :: weights[2]: 0.3078230661097493

# %%
for m in models:
    picture_plot.plot_images([m,], contours=True)

# %%
picture_plot.plot_images(models[2:3], contours=True, contour_lines=True, contour_line_level=1)

# %%
picture_plot.plot_images(models, pie_charts=True, pie_num=50, pie_chart_modus="light")
# Out:
# 10:39:51.468 DEBUG :: ['mu_x', 'variance_x', 'mu_y', 'variance_y']
# 10:39:51.520 DEBUG :: Axis-limits: Limits(x_min=3.634817156127011, x_max=9.025918046350725, y_min=1.4971193383546102, y_max=4.845885175622143)
# 10:39:52.488 DEBUG :: Axis-limits: Limits(x_min=3.6128416133543677, x_max=9.309873367387873, y_min=0.7490641641666419, y_max=7.739822421712751)
# 10:39:53.659 DEBUG :: Axis-limits: Limits(x_min=3.5960818016088765, x_max=9.086430670234604, y_min=-0.11790441803662022, y_max=3.152629779716469)
# 10:39:55.264 DEBUG :: Axis-limits: Limits(x_min=1.5664969655255938, x_max=4.960814398820434, y_min=0.7490569532104877, y_max=7.747805737859264)
# 10:39:57.339 WARNING :: Input [0.771545994192054] bigger than Max-Value [0.771214417748082] found
# 10:39:57.340 WARNING :: Input [0.771545994192054] bigger than Max-Value [0.771214417748082] found
# 10:39:57.340 WARNING :: Input [0.771545994192054] bigger than Max-Value [0.771214417748082] found
# 10:39:57.341 WARNING :: Input [0.771545994192054] bigger than Max-Value [0.771214417748082] found
# 10:39:57.341 WARNING :: Input [0.771545994192054] bigger than Max-Value [0.771214417748082] found
# 10:39:58.233 DEBUG :: Axis-limits: Limits(x_min=1.451805975786222, x_max=4.960814848079317, y_min=-0.16560364489685162, y_max=3.1562440386349815)
# 10:39:59.465 DEBUG :: Axis-limits: Limits(x_min=0.7490612787663297, x_max=7.6262176278822125, y_min=-0.16560337638995176, y_max=3.1291050836287218)

# %%
picture_plot.plot_images(models, crosses=True, contour_lines=True, cross_width=0.05, contour_line_level=2)
# Out:
# 10:40:52.576 DEBUG :: ['mu_x', 'variance_x', 'mu_y', 'variance_y']
