# %%
from contour_visualization import picture_plot, MixtureModel
# Out:
# 09:54:21.636 WARNING :: Using NumPy C-API based implementation for BLAS functions.

# %%
import pickle
import matplotlib.pyplot as plt

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
width = 9.5
height = 9.5
plt.rcParams['figure.figsize'] = [width, height]

# %%
model_test = pickle.load(open("../../fitted_models/mcg_iris_map.mdl", "rb"))

# %%
model_test.data.columns
# Out:
# Index(['species', 'sepal_length', 'sepal_width', 'petal_length',
#        'petal_width'],
#       dtype='object')

# %%
model_1 = MixtureModel.MixtureModel(model_test.data[["sepal_length", "sepal_width"]])

# %%
model_2 = MixtureModel.MixtureModel(model_test.data[["sepal_length", "petal_length"]])

# %%
model_3 = MixtureModel.MixtureModel(model_test.data[["sepal_length", "petal_width"]])

# %%
model_4 = MixtureModel.MixtureModel(model_test.data[["sepal_width", "petal_length"]])

# %%
model_5 = MixtureModel.MixtureModel(model_test.data[["sepal_width", "petal_width"]])

# %%
model_6 = MixtureModel.MixtureModel(model_test.data[["petal_length", "petal_width"]])

# %%
models = [model_1.get_gaussians(), model_2.get_gaussians(), model_3.get_gaussians(), model_4.get_gaussians(), model_5.get_gaussians(), model_6.get_gaussians()]
# Out:
# 09:54:21.998 INFO :: Means[0]: [4.98537147 3.45559252]
# 09:54:21.999 INFO :: Cov-Matrix[0]: [[0.11399981 0.09103105]
#  [0.09103105 0.1208071 ]]
# 09:54:21.999 INFO :: weights[0]: 0.316084148177187
# 09:54:22.000 INFO :: Means[1]: [6.65182243 3.037754  ]
# 09:54:22.001 INFO :: Cov-Matrix[1]: [[0.35227063 0.06827917]
#  [0.06827917 0.08722759]]
# 09:54:22.002 INFO :: weights[1]: 0.31351712141279775
# 09:54:22.003 INFO :: Means[2]: [5.86415676 2.7352466 ]
# 09:54:22.004 INFO :: Cov-Matrix[2]: [[0.28480826 0.0946101 ]
#  [0.0946101  0.09580995]]
# 09:54:22.004 INFO :: weights[2]: 0.3703987304100152
# 09:54:22.005 INFO :: Means[0]: [4.97500081 1.45908862]
# 09:54:22.006 INFO :: Cov-Matrix[0]: [[0.11596736 0.01556861]
#  [0.01556861 0.03150842]]
# 09:54:22.006 INFO :: weights[0]: 0.3259242202003243
# 09:54:22.007 INFO :: Means[1]: [6.00821904 4.41398863]
# 09:54:22.010 INFO :: Cov-Matrix[1]: [[0.28204142 0.23238634]
#  [0.23238634 0.32143389]]
# 09:54:22.011 INFO :: weights[1]: 0.3951954003670398
# 09:54:22.012 INFO :: Means[2]: [6.58862967 5.63119589]
# 09:54:22.013 INFO :: Cov-Matrix[2]: [[0.46282295 0.33019861]
#  [0.33019861 0.27789412]]
# 09:54:22.014 INFO :: weights[2]: 0.2788803794326358
# 09:54:22.015 INFO :: Means[0]: [4.97424985 0.23942576]
# 09:54:22.016 INFO :: Cov-Matrix[0]: [[0.1187092  0.00864992]
#  [0.00864992 0.0079803 ]]
# 09:54:22.017 INFO :: weights[0]: 0.31827394669711434
# 09:54:22.018 INFO :: Means[1]: [6.53814897 2.00764083]
# 09:54:22.019 INFO :: Cov-Matrix[1]: [[0.40585873 0.04826709]
#  [0.04826709 0.08193748]]
# 09:54:22.020 INFO :: weights[1]: 0.3455169918693259
# 09:54:22.021 INFO :: Means[2]: [5.92226048 1.31898983]
# 09:54:22.022 INFO :: Cov-Matrix[2]: [[0.30464385 0.09028205]
#  [0.09028205 0.05995515]]
# 09:54:22.022 INFO :: weights[2]: 0.3362090614335597
# 09:54:22.024 INFO :: Means[0]: [3.42727284 1.45909093]
# 09:54:22.025 INFO :: Cov-Matrix[0]: [[0.14698436 0.01066114]
#  [0.01066114 0.03150927]]
# 09:54:22.025 INFO :: weights[0]: 0.32592589272800815
# 09:54:22.026 INFO :: Means[1]: [2.81583524 4.4684791 ]
# 09:54:22.027 INFO :: Cov-Matrix[1]: [[0.09755288 0.11658242]
#  [0.11658242 0.35753463]]
# 09:54:22.031 INFO :: weights[1]: 0.4221768089349314
# 09:54:22.032 INFO :: Means[2]: [2.98518676 5.67027364]
# 09:54:22.032 INFO :: Cov-Matrix[2]: [[0.11938061 0.09304763]
#  [0.09304763 0.26975873]]
# 09:54:22.033 INFO :: weights[2]: 0.25189729833706054
# 09:54:22.034 INFO :: Means[0]: [3.42727274 0.24772727]
# 09:54:22.035 INFO :: Cov-Matrix[0]: [[0.14698446 0.00710744]
#  [0.00710744 0.01067765]]
# 09:54:22.035 INFO :: weights[0]: 0.32592592366131784
# 09:54:22.036 INFO :: Means[1]: [2.94753252 1.99195403]
# 09:54:22.037 INFO :: Cov-Matrix[1]: [[0.10130987 0.05910809]
#  [0.05910809 0.0847232 ]]
# 09:54:22.038 INFO :: weights[1]: 0.3615128329891796
# 09:54:22.039 INFO :: Means[2]: [2.79999499 1.31966345]
# 09:54:22.040 INFO :: Cov-Matrix[2]: [[0.11360085 0.05860929]
#  [0.05860929 0.04458837]]
# 09:54:22.040 INFO :: weights[2]: 0.3125612433495025
# 09:54:22.041 INFO :: Means[0]: [1.45908947 0.24772697]
# 09:54:22.042 INFO :: Cov-Matrix[0]: [[0.03150875 0.00604329]
#  [0.00604329 0.01067762]]
# 09:54:22.042 INFO :: weights[0]: 0.3259248081788392
# 09:54:22.043 INFO :: Means[1]: [4.33454169 1.37140143]
# 09:54:22.044 INFO :: Cov-Matrix[1]: [[0.26217894 0.10353727]
#  [0.10353727 0.05827643]]
# 09:54:22.045 INFO :: weights[1]: 0.3662521257114117
# 09:54:22.046 INFO :: Means[2]: [5.61128127 2.04765122]
# 09:54:22.046 INFO :: Cov-Matrix[2]: [[0.25374803 0.0312416 ]
#  [0.0312416  0.0730964 ]]
# 09:54:22.047 INFO :: weights[2]: 0.3078230661097493

# %%
picture_plot.plot_images(models, contours=True, contour_lines=True, contour_line_level=1)

# %%
for m in models:
    picture_plot.plot_images([m,], contours=True)

# %%
picture_plot.plot_images(models, pie_charts=True, pie_num=25)

# %%
picture_plot.plot_images(models, crosses=True, contour_lines=True, cross_width=0.05, contour_line_level=2)
# Out:
# 09:55:44.775 WARNING :: points in grid of z-coordinates to similar
# 09:55:44.776 WARNING :: points in grid of z-coordinates to similar
# 09:55:44.776 WARNING :: points in grid of z-coordinates to similar
# 09:55:44.777 WARNING :: points in grid of z-coordinates to similar
# 09:55:44.777 WARNING :: points in grid of z-coordinates to similar
# 09:55:44.806 WARNING :: points in grid of z-coordinates to similar
# 09:55:44.807 WARNING :: points in grid of z-coordinates to similar
# 09:55:44.807 WARNING :: points in grid of z-coordinates to similar
# 09:55:44.808 WARNING :: points in grid of z-coordinates to similar
# 09:55:44.808 WARNING :: points in grid of z-coordinates to similar
# 09:55:44.839 WARNING :: points in grid of z-coordinates to similar
# 09:55:44.839 WARNING :: points in grid of z-coordinates to similar
# 09:55:44.840 WARNING :: points in grid of z-coordinates to similar
# 09:55:44.840 WARNING :: points in grid of z-coordinates to similar
# 09:55:44.871 WARNING :: points in grid of z-coordinates to similar
# 09:55:44.872 WARNING :: points in grid of z-coordinates to similar
# 09:55:44.872 WARNING :: points in grid of z-coordinates to similar
# 09:55:44.873 WARNING :: points in grid of z-coordinates to similar
# 09:55:44.873 WARNING :: points in grid of z-coordinates to similar
# 09:55:44.902 WARNING :: points in grid of z-coordinates to similar
# 09:55:44.903 WARNING :: points in grid of z-coordinates to similar
# 09:55:44.903 WARNING :: points in grid of z-coordinates to similar
# 09:55:44.903 WARNING :: points in grid of z-coordinates to similar
# 09:55:44.929 WARNING :: points in grid of z-coordinates to similar
# 09:55:44.930 WARNING :: points in grid of z-coordinates to similar
# 09:55:44.930 WARNING :: points in grid of z-coordinates to similar
# 09:55:44.931 WARNING :: points in grid of z-coordinates to similar
# 09:55:44.931 WARNING :: points in grid of z-coordinates to similar
# 09:55:44.998 WARNING :: points in grid of z-coordinates to similar
# 09:55:44.999 WARNING :: points in grid of z-coordinates to similar
# 09:55:44.999 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.000 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.000 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.028 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.029 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.029 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.030 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.030 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.058 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.059 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.059 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.059 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.086 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.087 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.088 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.088 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.089 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.115 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.115 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.116 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.141 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.141 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.142 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.142 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.143 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.209 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.210 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.210 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.211 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.211 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.237 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.238 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.238 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.238 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.239 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.266 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.266 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.267 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.267 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.294 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.295 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.295 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.295 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.296 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.322 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.323 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.323 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.323 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.349 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.350 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.350 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.351 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.351 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.417 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.418 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.418 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.418 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.419 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.444 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.445 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.445 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.446 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.446 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.472 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.472 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.473 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.473 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.500 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.501 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.501 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.502 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.503 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.531 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.532 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.532 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.533 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.559 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.559 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.560 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.560 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.560 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.624 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.625 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.625 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.625 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.626 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.651 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.652 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.653 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.653 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.653 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.679 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.680 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.680 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.681 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.681 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.706 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.707 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.707 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.707 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.708 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.734 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.735 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.735 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.736 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.736 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.763 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.764 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.764 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.765 WARNING :: points in grid of z-coordinates to similar
# 09:55:45.765 WARNING :: points in grid of z-coordinates to similar
# 09:55:46.021 WARNING :: points in grid of z-coordinates to similar
# 09:55:46.021 WARNING :: points in grid of z-coordinates to similar
# 09:55:46.022 WARNING :: points in grid of z-coordinates to similar
# 09:55:46.022 WARNING :: points in grid of z-coordinates to similar
# 09:55:46.023 WARNING :: points in grid of z-coordinates to similar
# 09:55:46.054 WARNING :: points in grid of z-coordinates to similar
# 09:55:46.055 WARNING :: points in grid of z-coordinates to similar
# 09:55:46.055 WARNING :: points in grid of z-coordinates to similar
# 09:55:46.055 WARNING :: points in grid of z-coordinates to similar
# 09:55:46.056 WARNING :: points in grid of z-coordinates to similar
# 09:55:46.089 WARNING :: points in grid of z-coordinates to similar
# 09:55:46.090 WARNING :: points in grid of z-coordinates to similar
# 09:55:46.091 WARNING :: points in grid of z-coordinates to similar
# 09:55:46.091 WARNING :: points in grid of z-coordinates to similar
# 09:55:46.130 WARNING :: points in grid of z-coordinates to similar
# 09:55:46.131 WARNING :: points in grid of z-coordinates to similar
# 09:55:46.131 WARNING :: points in grid of z-coordinates to similar
# 09:55:46.132 WARNING :: points in grid of z-coordinates to similar
# 09:55:46.132 WARNING :: points in grid of z-coordinates to similar
# 09:55:46.162 WARNING :: points in grid of z-coordinates to similar
# 09:55:46.162 WARNING :: points in grid of z-coordinates to similar
# 09:55:46.163 WARNING :: points in grid of z-coordinates to similar
# 09:55:46.163 WARNING :: points in grid of z-coordinates to similar
# 09:55:46.163 WARNING :: points in grid of z-coordinates to similar
# 09:55:46.190 WARNING :: points in grid of z-coordinates to similar
# 09:55:46.190 WARNING :: points in grid of z-coordinates to similar
# 09:55:46.191 WARNING :: points in grid of z-coordinates to similar
# 09:55:46.191 WARNING :: points in grid of z-coordinates to similar
# 09:55:46.191 WARNING :: points in grid of z-coordinates to similar
