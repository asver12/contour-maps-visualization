# %%
from contour_visualization import picture_plot, MixtureModel

# %%
import pickle
import matplotlib.pyplot as plt

# %%
import logging
logger = logging.getLogger("contour_visualization.picture_plot")
logger.setLevel(logging.DEBUG)

# %%
# %load_ext autoreload
# %autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
width = 9.5
height = 9.5
plt.rcParams['figure.figsize'] = [width, height]

# %%
model_test = pickle.load(open("../../fitted_models/mcg_iris_map.mdl", "rb"))

# %%
model_test.data.columns
# Out:
# Index(['species', 'sepal_length', 'sepal_width', 'petal_length',
#        'petal_width'],
#       dtype='object')

# %%
model_1 = MixtureModel.MixtureModel(model_test.data[["sepal_length", "sepal_width"]])

# %%
model_2 = MixtureModel.MixtureModel(model_test.data[["sepal_length", "petal_length"]])

# %%
model_3 = MixtureModel.MixtureModel(model_test.data[["sepal_length", "petal_width"]])

# %%
model_4 = MixtureModel.MixtureModel(model_test.data[["sepal_width", "petal_length"]])

# %%
model_5 = MixtureModel.MixtureModel(model_test.data[["sepal_width", "petal_width"]])

# %%
model_6 = MixtureModel.MixtureModel(model_test.data[["petal_length", "petal_width"]])

# %%
models = [model_1.get_gaussians(), model_2.get_gaussians(), model_3.get_gaussians(), model_4.get_gaussians(), model_5.get_gaussians(), model_6.get_gaussians()]
# Out:
# 10:49:39.963 INFO :: Means[0]: [0.19036036 0.60650443]
# 10:49:39.964 INFO :: Cov-Matrix[0]: [[0.00879602 0.01053765]
#  [0.01053765 0.02097761]]
# 10:49:39.965 INFO :: weights[0]: 0.3159845546968475
# 10:49:39.966 INFO :: Means[1]: [0.44508485 0.30871215]
# 10:49:39.967 INFO :: Cov-Matrix[1]: [[0.02284479 0.01106034]
#  [0.01106034 0.01635687]]
# 10:49:39.968 INFO :: weights[1]: 0.4023372192262877
# 10:49:39.969 INFO :: Means[2]: [0.66281585 0.44337229]
# 10:49:39.970 INFO :: Cov-Matrix[2]: [[0.02752619 0.00675629]
#  [0.00675629 0.01429797]]
# 10:49:39.971 INFO :: weights[2]: 0.28167822607686477
# 10:49:39.972 INFO :: Means[0]: [0.18750384 0.08053446]
# 10:49:39.973 INFO :: Cov-Matrix[0]: [[0.00894966 0.00075903]
#  [0.00075903 0.00097028]]
# 10:49:39.974 INFO :: weights[0]: 0.32589185743978194
# 10:49:39.978 INFO :: Means[1]: [0.64355921 0.76563405]
# 10:49:39.978 INFO :: Cov-Matrix[1]: [[0.02842672 0.01666097]
#  [0.01666097 0.01558593]]
# 10:49:39.979 INFO :: weights[1]: 0.3336841455637322
# 10:49:39.980 INFO :: Means[2]: [0.44084567 0.61045401]
# 10:49:39.980 INFO :: Cov-Matrix[2]: [[0.01881526 0.01098247]
#  [0.01098247 0.01322529]]
# 10:49:39.982 INFO :: weights[2]: 0.3404239969964857
# 10:49:39.983 INFO :: Means[0]: [0.18727495 0.05802645]
# 10:49:39.984 INFO :: Cov-Matrix[0]: [[0.00916514 0.00099986]
#  [0.00099986 0.00137911]]
# 10:49:39.985 INFO :: weights[0]: 0.3180827788959487
# 10:49:39.986 INFO :: Means[1]: [0.62325036 0.80838715]
# 10:49:39.986 INFO :: Cov-Matrix[1]: [[0.03184977 0.00538594]
#  [0.00538594 0.01251705]]
# 10:49:39.987 INFO :: weights[1]: 0.3177174200031563
# 10:49:39.988 INFO :: Means[2]: [0.46221742 0.51782838]
# 10:49:39.989 INFO :: Cov-Matrix[2]: [[0.02529344 0.01149682]
#  [0.01149682 0.01149593]]
# 10:49:39.990 INFO :: weights[2]: 0.36419980110089495
# 10:49:39.991 INFO :: Means[0]: [0.50034824 0.07377046]
# 10:49:39.992 INFO :: Cov-Matrix[0]: [[0.01804253 0.00112405]
#  [0.00112405 0.00051788]]
# 10:49:39.993 INFO :: weights[0]: 0.12469504008615265
# 10:49:39.994 INFO :: Means[1]: [0.36629645 0.68728481]
# 10:49:39.995 INFO :: Cov-Matrix[1]: [[0.0195192  0.01136356]
#  [0.01136356 0.02040637]]
# 10:49:39.995 INFO :: weights[1]: 0.6740850719853809
# 10:49:39.996 INFO :: Means[2]: [0.65319005 0.08474023]
# 10:49:39.997 INFO :: Cov-Matrix[2]: [[ 2.12036818e-02 -7.64507242e-05]
#  [-7.64507242e-05  1.20541356e-03]]
# 10:49:39.998 INFO :: weights[2]: 0.20121988792846646
# 10:49:39.999 INFO :: Means[0]: [0.59469697 0.06155303]
# 10:49:39.999 INFO :: Cov-Matrix[0]: [[0.02551896 0.00123393]
#  [0.00123393 0.00185459]]
# 10:49:40.000 INFO :: weights[0]: 0.3259259236545182
# 10:49:40.001 INFO :: Means[1]: [0.394814   0.78832855]
# 10:49:40.001 INFO :: Cov-Matrix[1]: [[0.01758864 0.01026016]
#  [0.01026016 0.01470748]]
# 10:49:40.002 INFO :: weights[1]: 0.3614863140997898
# 10:49:40.003 INFO :: Means[2]: [0.3333263  0.50820025]
# 10:49:40.003 INFO :: Cov-Matrix[2]: [[0.0197229  0.01017475]
#  [0.01017475 0.00774239]]
# 10:49:40.004 INFO :: weights[2]: 0.312587762245692
# 10:49:40.004 INFO :: Means[0]: [0.08054214 0.06155289]
# 10:49:40.005 INFO :: Cov-Matrix[0]: [[0.00097078 0.00044176]
#  [0.00044176 0.00185458]]
# 10:49:40.005 INFO :: weights[0]: 0.32592530361894395
# 10:49:40.006 INFO :: Means[1]: [0.57402168 0.51145514]
# 10:49:40.007 INFO :: Cov-Matrix[1]: [[0.00749525 0.00619135]
#  [0.00619135 0.00748749]]
# 10:49:40.007 INFO :: weights[1]: 0.3297770734899325
# 10:49:40.008 INFO :: Means[2]: [0.79579042 0.79919536]
# 10:49:40.008 INFO :: Cov-Matrix[2]: [[0.00870028 0.00360296]
#  [0.00360296 0.01300077]]
# 10:49:40.009 INFO :: weights[2]: 0.3442976228911235

# %%
for m in models:
    picture_plot.plot_images([m,], contours=True)
# Out:
# 10:49:41.048 DEBUG :: ['mu_x', 'variance_x', 'mu_y', 'variance_y']
# 10:49:41.076 DEBUG :: Axis-limits: Limits(x_min=-0.1847881131564627, x_max=1.3264566049966078, y_min=-0.2028637143352791, y_max=1.1858503696006601)
# 10:49:42.593 DEBUG :: ['mu_x', 'variance_x', 'mu_y', 'variance_y']
# 10:49:42.618 DEBUG :: Axis-limits: Limits(x_min=-0.19090678223087365, x_max=1.3179682036921598, y_min=-0.04406277238606107, y_max=1.2650085591782343)
# 10:49:44.189 DEBUG :: ['mu_x', 'variance_x', 'mu_y', 'variance_y']
# 10:49:44.210 DEBUG :: Axis-limits: Limits(x_min=-0.19566401684472096, x_max=1.337110456073209, y_min=-0.09051903660511279, y_max=1.2559056921122247)
# 10:49:45.721 DEBUG :: ['mu_x', 'variance_x', 'mu_y', 'variance_y']
# 10:49:45.742 DEBUG :: Axis-limits: Limits(x_min=-0.19254804798713576, x_max=1.235649408993184, y_min=-0.05413603113199471, y_max=1.2586882272451412)
# 10:49:47.226 DEBUG :: ['mu_x', 'variance_x', 'mu_y', 'variance_y']
# 10:49:47.248 DEBUG :: Axis-limits: Limits(x_min=-0.22842673428434107, x_max=1.2336831996587707, y_min=-0.11070656841941394, y_max=1.2734261046067339)
# 10:49:48.736 DEBUG :: ['mu_x', 'variance_x', 'mu_y', 'variance_y']
# 10:49:48.757 DEBUG :: Axis-limits: Limits(x_min=-0.044086999570665794, x_max=1.1688916580007644, y_min=-0.11070626462981568, y_max=1.2552790654216501)

# %%
picture_plot.plot_images(models[2:3], contours=True, contour_lines=True, contour_line_level=1)

# %%
picture_plot.plot_images(models, pie_charts=True, pie_num=50, pie_chart_modus="light")
# Out:
# 10:50:07.584 DEBUG :: ['mu_x', 'variance_x', 'mu_y', 'variance_y']
# 10:50:07.637 DEBUG :: Axis-limits: Limits(x_min=-0.1847881131564627, x_max=1.3264566049966078, y_min=-0.2028637143352791, y_max=1.1858503696006601)
# 10:50:09.011 DEBUG :: Axis-limits: Limits(x_min=-0.19090678223087365, x_max=1.3179682036921598, y_min=-0.04406277238606107, y_max=1.2650085591782343)
# 10:50:10.757 DEBUG :: Axis-limits: Limits(x_min=-0.19566401684472096, x_max=1.337110456073209, y_min=-0.09051903660511279, y_max=1.2559056921122247)
# 10:50:12.113 DEBUG :: Axis-limits: Limits(x_min=-0.19254804798713576, x_max=1.235649408993184, y_min=-0.05413603113199471, y_max=1.2586882272451412)
# 10:50:13.431 DEBUG :: Axis-limits: Limits(x_min=-0.22842673428434107, x_max=1.2336831996587707, y_min=-0.11070656841941394, y_max=1.2734261046067339)
# 10:50:14.850 DEBUG :: Axis-limits: Limits(x_min=-0.044086999570665794, x_max=1.1688916580007644, y_min=-0.11070626462981568, y_max=1.2552790654216501)

# %%
picture_plot.plot_images(models, crosses=True, contour_lines=True, cross_width=0.005, contour_line_level=2)
# Out:
# 10:50:21.787 DEBUG :: ['mu_x', 'variance_x', 'mu_y', 'variance_y']
# 10:50:21.858 DEBUG :: Axis-limits: Limits(x_min=-0.1847881131564627, x_max=1.3264566049966078, y_min=-0.2028637143352791, y_max=1.1858503696006601)
# 10:50:21.887 WARNING :: points in grid of z-coordinates to similar
# 10:50:21.889 WARNING :: points in grid of z-coordinates to similar
# 10:50:21.889 WARNING :: points in grid of z-coordinates to similar
# 10:50:21.890 WARNING :: points in grid of z-coordinates to similar
# 10:50:21.890 WARNING :: points in grid of z-coordinates to similar
# 10:50:21.939 WARNING :: points in grid of z-coordinates to similar
# 10:50:21.940 WARNING :: points in grid of z-coordinates to similar
# 10:50:21.941 WARNING :: points in grid of z-coordinates to similar
# 10:50:21.941 WARNING :: points in grid of z-coordinates to similar
# 10:50:21.943 WARNING :: points in grid of z-coordinates to similar
# 10:50:21.980 WARNING :: points in grid of z-coordinates to similar
# 10:50:21.980 WARNING :: points in grid of z-coordinates to similar
# 10:50:21.981 WARNING :: points in grid of z-coordinates to similar
# 10:50:21.982 WARNING :: points in grid of z-coordinates to similar
# 10:50:21.982 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.013 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.014 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.014 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.015 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.015 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.049 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.050 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.051 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.051 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.052 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.085 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.086 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.086 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.087 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.087 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.149 DEBUG :: Axis-limits: Limits(x_min=-0.19090678223087365, x_max=1.3179682036921598, y_min=-0.04406277238606107, y_max=1.2650085591782343)
# 10:50:22.172 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.173 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.173 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.173 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.174 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.209 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.210 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.211 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.212 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.212 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.248 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.249 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.249 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.250 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.250 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.284 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.285 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.286 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.286 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.287 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.322 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.323 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.323 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.324 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.324 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.359 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.360 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.360 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.361 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.361 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.427 DEBUG :: Axis-limits: Limits(x_min=-0.19566401684472096, x_max=1.337110456073209, y_min=-0.09051903660511279, y_max=1.2559056921122247)
# 10:50:22.451 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.452 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.452 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.453 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.453 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.489 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.490 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.491 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.491 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.492 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.527 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.527 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.528 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.528 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.529 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.560 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.561 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.562 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.562 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.563 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.596 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.597 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.597 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.598 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.598 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.632 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.632 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.633 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.633 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.634 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.690 DEBUG :: Axis-limits: Limits(x_min=-0.19254804798713576, x_max=1.235649408993184, y_min=-0.05413603113199471, y_max=1.2586882272451412)
# 10:50:22.711 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.711 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.712 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.712 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.713 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.751 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.752 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.752 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.753 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.754 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.792 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.793 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.794 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.794 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.795 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.830 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.831 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.831 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.832 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.832 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.867 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.868 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.868 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.869 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.870 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.907 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.909 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.909 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.910 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.910 WARNING :: points in grid of z-coordinates to similar
# 10:50:22.982 DEBUG :: Axis-limits: Limits(x_min=-0.22842673428434107, x_max=1.2336831996587707, y_min=-0.11070656841941394, y_max=1.2734261046067339)
# 10:50:23.003 WARNING :: points in grid of z-coordinates to similar
# 10:50:23.004 WARNING :: points in grid of z-coordinates to similar
# 10:50:23.005 WARNING :: points in grid of z-coordinates to similar
# 10:50:23.005 WARNING :: points in grid of z-coordinates to similar
# 10:50:23.006 WARNING :: points in grid of z-coordinates to similar
# 10:50:23.040 WARNING :: points in grid of z-coordinates to similar
# 10:50:23.041 WARNING :: points in grid of z-coordinates to similar
# 10:50:23.041 WARNING :: points in grid of z-coordinates to similar
# 10:50:23.042 WARNING :: points in grid of z-coordinates to similar
# 10:50:23.042 WARNING :: points in grid of z-coordinates to similar
# 10:50:23.078 WARNING :: points in grid of z-coordinates to similar
# 10:50:23.078 WARNING :: points in grid of z-coordinates to similar
# 10:50:23.079 WARNING :: points in grid of z-coordinates to similar
# 10:50:23.080 WARNING :: points in grid of z-coordinates to similar
# 10:50:23.080 WARNING :: points in grid of z-coordinates to similar
# 10:50:23.114 WARNING :: points in grid of z-coordinates to similar
# 10:50:23.115 WARNING :: points in grid of z-coordinates to similar
# 10:50:23.115 WARNING :: points in grid of z-coordinates to similar
# 10:50:23.116 WARNING :: points in grid of z-coordinates to similar
# 10:50:23.117 WARNING :: points in grid of z-coordinates to similar
# 10:50:23.152 WARNING :: points in grid of z-coordinates to similar
# 10:50:23.153 WARNING :: points in grid of z-coordinates to similar
# 10:50:23.153 WARNING :: points in grid of z-coordinates to similar
# 10:50:23.154 WARNING :: points in grid of z-coordinates to similar
# 10:50:23.154 WARNING :: points in grid of z-coordinates to similar
# 10:50:23.191 WARNING :: points in grid of z-coordinates to similar
# 10:50:23.192 WARNING :: points in grid of z-coordinates to similar
# 10:50:23.192 WARNING :: points in grid of z-coordinates to similar
# 10:50:23.193 WARNING :: points in grid of z-coordinates to similar
# 10:50:23.194 WARNING :: points in grid of z-coordinates to similar
# 10:50:23.268 DEBUG :: Axis-limits: Limits(x_min=-0.044086999570665794, x_max=1.1688916580007644, y_min=-0.11070626462981568, y_max=1.2552790654216501)
# 10:50:23.288 WARNING :: points in grid of z-coordinates to similar
# 10:50:23.289 WARNING :: points in grid of z-coordinates to similar
# 10:50:23.290 WARNING :: points in grid of z-coordinates to similar
# 10:50:23.290 WARNING :: points in grid of z-coordinates to similar
# 10:50:23.291 WARNING :: points in grid of z-coordinates to similar
# 10:50:23.324 WARNING :: points in grid of z-coordinates to similar
# 10:50:23.325 WARNING :: points in grid of z-coordinates to similar
# 10:50:23.326 WARNING :: points in grid of z-coordinates to similar
# 10:50:23.326 WARNING :: points in grid of z-coordinates to similar
# 10:50:23.327 WARNING :: points in grid of z-coordinates to similar
# 10:50:23.360 WARNING :: points in grid of z-coordinates to similar
# 10:50:23.360 WARNING :: points in grid of z-coordinates to similar
# 10:50:23.361 WARNING :: points in grid of z-coordinates to similar
# 10:50:23.361 WARNING :: points in grid of z-coordinates to similar
# 10:50:23.362 WARNING :: points in grid of z-coordinates to similar
# 10:50:23.403 WARNING :: points in grid of z-coordinates to similar
# 10:50:23.404 WARNING :: points in grid of z-coordinates to similar
# 10:50:23.404 WARNING :: points in grid of z-coordinates to similar
# 10:50:23.405 WARNING :: points in grid of z-coordinates to similar
# 10:50:23.406 WARNING :: points in grid of z-coordinates to similar
# 10:50:23.453 WARNING :: points in grid of z-coordinates to similar
# 10:50:23.453 WARNING :: points in grid of z-coordinates to similar
# 10:50:23.454 WARNING :: points in grid of z-coordinates to similar
# 10:50:23.454 WARNING :: points in grid of z-coordinates to similar
# 10:50:23.455 WARNING :: points in grid of z-coordinates to similar
# 10:50:23.499 WARNING :: points in grid of z-coordinates to similar
# 10:50:23.499 WARNING :: points in grid of z-coordinates to similar
# 10:50:23.500 WARNING :: points in grid of z-coordinates to similar
# 10:50:23.501 WARNING :: points in grid of z-coordinates to similar
# 10:50:23.502 WARNING :: points in grid of z-coordinates to similar
