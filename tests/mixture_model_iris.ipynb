# %%
from contour_visualization import picture_plot, MixtureModel
# Out:
# 11:37:48.376 WARNING :: Using NumPy C-API based implementation for BLAS functions.

# %%
import pickle
import matplotlib.pyplot as plt

# %%
width = 9.5
height = 9.5
plt.rcParams['figure.figsize'] = [width, height]

# %%
model_test = pickle.load(open("../../fitted_models/mcg_iris_map.mdl", "rb"))

# %%
model_test.data.columns
# Out:
# Index(['species', 'sepal_length', 'sepal_width', 'petal_length',
#        'petal_width'],
#       dtype='object')

# %%
model_1 = MixtureModel.MixtureModel(model_test.data[["sepal_length", "sepal_width"]])

# %%
model_2 = MixtureModel.MixtureModel(model_test.data[["sepal_length", "petal_length"]])

# %%
model_3 = MixtureModel.MixtureModel(model_test.data[["sepal_length", "petal_width"]])

# %%
model_4 = MixtureModel.MixtureModel(model_test.data[["sepal_width", "petal_length"]])

# %%
model_5 = MixtureModel.MixtureModel(model_test.data[["sepal_width", "petal_width"]])

# %%
model_6 = MixtureModel.MixtureModel(model_test.data[["petal_length", "petal_width"]])

# %%
models = [model_1.get_gaussians(), model_2.get_gaussians(), model_3.get_gaussians(), model_4.get_gaussians(), model_5.get_gaussians(), model_6.get_gaussians()]
# Out:
# 11:40:08.698 INFO :: Means[0]: [4.98537147 3.45559252]
# 11:40:08.699 INFO :: Cov-Matrix[0]: [[0.11399981 0.09103105]
#  [0.09103105 0.1208071 ]]
# 11:40:08.700 INFO :: weights[0]: 0.316084148177187
# 11:40:08.701 INFO :: Means[1]: [6.65182243 3.037754  ]
# 11:40:08.702 INFO :: Cov-Matrix[1]: [[0.35227063 0.06827917]
#  [0.06827917 0.08722759]]
# 11:40:08.703 INFO :: weights[1]: 0.31351712141279775
# 11:40:08.704 INFO :: Means[2]: [5.86415676 2.7352466 ]
# 11:40:08.705 INFO :: Cov-Matrix[2]: [[0.28480826 0.0946101 ]
#  [0.0946101  0.09580995]]
# 11:40:08.706 INFO :: weights[2]: 0.3703987304100152
# 11:40:08.708 INFO :: Means[0]: [4.97500081 1.45908862]
# 11:40:08.710 INFO :: Cov-Matrix[0]: [[0.11596736 0.01556861]
#  [0.01556861 0.03150842]]
# 11:40:08.710 INFO :: weights[0]: 0.3259242202003243
# 11:40:08.711 INFO :: Means[1]: [6.00821904 4.41398863]
# 11:40:08.712 INFO :: Cov-Matrix[1]: [[0.28204142 0.23238634]
#  [0.23238634 0.32143389]]
# 11:40:08.713 INFO :: weights[1]: 0.3951954003670398
# 11:40:08.713 INFO :: Means[2]: [6.58862967 5.63119589]
# 11:40:08.714 INFO :: Cov-Matrix[2]: [[0.46282295 0.33019861]
#  [0.33019861 0.27789412]]
# 11:40:08.714 INFO :: weights[2]: 0.2788803794326358
# 11:40:08.716 INFO :: Means[0]: [4.97424985 0.23942576]
# 11:40:08.717 INFO :: Cov-Matrix[0]: [[0.1187092  0.00864992]
#  [0.00864992 0.0079803 ]]
# 11:40:08.717 INFO :: weights[0]: 0.31827394669711434
# 11:40:08.719 INFO :: Means[1]: [6.53814897 2.00764083]
# 11:40:08.720 INFO :: Cov-Matrix[1]: [[0.40585873 0.04826709]
#  [0.04826709 0.08193748]]
# 11:40:08.722 INFO :: weights[1]: 0.3455169918693259
# 11:40:08.723 INFO :: Means[2]: [5.92226048 1.31898983]
# 11:40:08.724 INFO :: Cov-Matrix[2]: [[0.30464385 0.09028205]
#  [0.09028205 0.05995515]]
# 11:40:08.725 INFO :: weights[2]: 0.3362090614335597
# 11:40:08.727 INFO :: Means[0]: [3.42727284 1.45909093]
# 11:40:08.728 INFO :: Cov-Matrix[0]: [[0.14698436 0.01066114]
#  [0.01066114 0.03150927]]
# 11:40:08.729 INFO :: weights[0]: 0.32592589272800815
# 11:40:08.730 INFO :: Means[1]: [2.81583524 4.4684791 ]
# 11:40:08.730 INFO :: Cov-Matrix[1]: [[0.09755288 0.11658242]
#  [0.11658242 0.35753463]]
# 11:40:08.731 INFO :: weights[1]: 0.4221768089349314
# 11:40:08.732 INFO :: Means[2]: [2.98518676 5.67027364]
# 11:40:08.732 INFO :: Cov-Matrix[2]: [[0.11938061 0.09304763]
#  [0.09304763 0.26975873]]
# 11:40:08.733 INFO :: weights[2]: 0.25189729833706054
# 11:40:08.734 INFO :: Means[0]: [3.42727274 0.24772727]
# 11:40:08.735 INFO :: Cov-Matrix[0]: [[0.14698446 0.00710744]
#  [0.00710744 0.01067765]]
# 11:40:08.735 INFO :: weights[0]: 0.32592592366131784
# 11:40:08.736 INFO :: Means[1]: [2.94753252 1.99195403]
# 11:40:08.737 INFO :: Cov-Matrix[1]: [[0.10130987 0.05910809]
#  [0.05910809 0.0847232 ]]
# 11:40:08.737 INFO :: weights[1]: 0.3615128329891796
# 11:40:08.738 INFO :: Means[2]: [2.79999499 1.31966345]
# 11:40:08.739 INFO :: Cov-Matrix[2]: [[0.11360085 0.05860929]
#  [0.05860929 0.04458837]]
# 11:40:08.739 INFO :: weights[2]: 0.3125612433495025
# 11:40:08.740 INFO :: Means[0]: [1.45908947 0.24772697]
# 11:40:08.742 INFO :: Cov-Matrix[0]: [[0.03150875 0.00604329]
#  [0.00604329 0.01067762]]
# 11:40:08.744 INFO :: weights[0]: 0.3259248081788392
# 11:40:08.746 INFO :: Means[1]: [4.33454169 1.37140143]
# 11:40:08.747 INFO :: Cov-Matrix[1]: [[0.26217894 0.10353727]
#  [0.10353727 0.05827643]]
# 11:40:08.748 INFO :: weights[1]: 0.3662521257114117
# 11:40:08.749 INFO :: Means[2]: [5.61128127 2.04765122]
# 11:40:08.754 INFO :: Cov-Matrix[2]: [[0.25374803 0.0312416 ]
#  [0.0312416  0.0730964 ]]
# 11:40:08.755 INFO :: weights[2]: 0.3078230661097493

# %%
for m in models:
    picture_plot.plot_images([m,], contours=True)

# %%
for m in models:
    picture_plot.plot_images([m,], pie_charts=True, pie_num=25)

# %%
picture_plot.plot_images(models, contours=True, contour_lines=True, contour_line_level=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-f9b1c1a5cf40> in <module>
# ----> 1 picture_plot.plot_images(models, contours=True, contour_lines=True, contour_line_level=1)
#
# ~/Documents/git/contour-maps-visualization/contour_visualization/picture_plot.py in plot_images(distributions, plot_titles, titles, colors, columns, bottom, left, right, top, *args, **kwargs)
#      50                 if plot_titles:
#      51                     title = _generate_title(titles, distributions[i * columns], i * columns)
# ---> 52                 plot_image(ax[i * columns], distributions[i * columns], title=title, legend=True,
#      53                            legend_colors=color_legend, *args,
#      54                            **kwargs)
#
# TypeError: 'AxesSubplot' object does not support indexing

# %%
picture_plot.plot_images(models, pie_charts=True, pie_num=25)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-e805c4d6e85c> in <module>
# ----> 1 picture_plot.plot_images(models, pie_charts=True, pie_num=25)
#
# ~/Documents/git/contour-maps-visualization/contour_visualization/picture_plot.py in plot_images(distributions, plot_titles, titles, colors, columns, bottom, left, right, top, *args, **kwargs)
#      50                 if plot_titles:
#      51                     title = _generate_title(titles, distributions[i * columns], i * columns)
# ---> 52                 plot_image(ax[i * columns], distributions[i * columns], title=title, legend=True,
#      53                            legend_colors=color_legend, *args,
#      54                            **kwargs)
#
# TypeError: 'AxesSubplot' object does not support indexing

# %%
picture_plot.plot_images(models, crosses=True, contour_lines=True, cross_width=0.05, contour_line_level=2)
# Out:
# 11:42:36.646 WARNING :: points in grid of z-coordinates to similar
# 11:42:36.646 WARNING :: points in grid of z-coordinates to similar
# 11:42:36.647 WARNING :: points in grid of z-coordinates to similar
# 11:42:36.647 WARNING :: points in grid of z-coordinates to similar
# 11:42:36.647 WARNING :: points in grid of z-coordinates to similar
# 11:42:36.675 WARNING :: points in grid of z-coordinates to similar
# 11:42:36.676 WARNING :: points in grid of z-coordinates to similar
# 11:42:36.677 WARNING :: points in grid of z-coordinates to similar
# 11:42:36.677 WARNING :: points in grid of z-coordinates to similar
# 11:42:36.677 WARNING :: points in grid of z-coordinates to similar
# 11:42:36.707 WARNING :: points in grid of z-coordinates to similar
# 11:42:36.707 WARNING :: points in grid of z-coordinates to similar
# 11:42:36.707 WARNING :: points in grid of z-coordinates to similar
# 11:42:36.708 WARNING :: points in grid of z-coordinates to similar
# 11:42:36.737 WARNING :: points in grid of z-coordinates to similar
# 11:42:36.738 WARNING :: points in grid of z-coordinates to similar
# 11:42:36.738 WARNING :: points in grid of z-coordinates to similar
# 11:42:36.739 WARNING :: points in grid of z-coordinates to similar
# 11:42:36.739 WARNING :: points in grid of z-coordinates to similar
# 11:42:36.770 WARNING :: points in grid of z-coordinates to similar
# 11:42:36.771 WARNING :: points in grid of z-coordinates to similar
# 11:42:36.771 WARNING :: points in grid of z-coordinates to similar
# 11:42:36.771 WARNING :: points in grid of z-coordinates to similar
# 11:42:36.798 WARNING :: points in grid of z-coordinates to similar
# 11:42:36.798 WARNING :: points in grid of z-coordinates to similar
# 11:42:36.799 WARNING :: points in grid of z-coordinates to similar
# 11:42:36.799 WARNING :: points in grid of z-coordinates to similar
# 11:42:36.800 WARNING :: points in grid of z-coordinates to similar
# 11:42:36.867 WARNING :: points in grid of z-coordinates to similar
# 11:42:36.868 WARNING :: points in grid of z-coordinates to similar
# 11:42:36.868 WARNING :: points in grid of z-coordinates to similar
# 11:42:36.868 WARNING :: points in grid of z-coordinates to similar
# 11:42:36.869 WARNING :: points in grid of z-coordinates to similar
# 11:42:36.894 WARNING :: points in grid of z-coordinates to similar
# 11:42:36.894 WARNING :: points in grid of z-coordinates to similar
# 11:42:36.894 WARNING :: points in grid of z-coordinates to similar
# 11:42:36.895 WARNING :: points in grid of z-coordinates to similar
# 11:42:36.895 WARNING :: points in grid of z-coordinates to similar
# 11:42:36.921 WARNING :: points in grid of z-coordinates to similar
# 11:42:36.921 WARNING :: points in grid of z-coordinates to similar
# 11:42:36.922 WARNING :: points in grid of z-coordinates to similar
# 11:42:36.922 WARNING :: points in grid of z-coordinates to similar
# 11:42:36.947 WARNING :: points in grid of z-coordinates to similar
# 11:42:36.947 WARNING :: points in grid of z-coordinates to similar
# 11:42:36.948 WARNING :: points in grid of z-coordinates to similar
# 11:42:36.948 WARNING :: points in grid of z-coordinates to similar
# 11:42:36.949 WARNING :: points in grid of z-coordinates to similar
# 11:42:36.975 WARNING :: points in grid of z-coordinates to similar
# 11:42:36.975 WARNING :: points in grid of z-coordinates to similar
# 11:42:36.976 WARNING :: points in grid of z-coordinates to similar
# 11:42:37.003 WARNING :: points in grid of z-coordinates to similar
# 11:42:37.003 WARNING :: points in grid of z-coordinates to similar
# 11:42:37.004 WARNING :: points in grid of z-coordinates to similar
# 11:42:37.004 WARNING :: points in grid of z-coordinates to similar
# 11:42:37.005 WARNING :: points in grid of z-coordinates to similar
# 11:42:37.070 WARNING :: points in grid of z-coordinates to similar
# 11:42:37.071 WARNING :: points in grid of z-coordinates to similar
# 11:42:37.071 WARNING :: points in grid of z-coordinates to similar
# 11:42:37.071 WARNING :: points in grid of z-coordinates to similar
# 11:42:37.072 WARNING :: points in grid of z-coordinates to similar
# 11:42:37.098 WARNING :: points in grid of z-coordinates to similar
# 11:42:37.099 WARNING :: points in grid of z-coordinates to similar
# 11:42:37.099 WARNING :: points in grid of z-coordinates to similar
# 11:42:37.099 WARNING :: points in grid of z-coordinates to similar
# 11:42:37.100 WARNING :: points in grid of z-coordinates to similar
# 11:42:37.126 WARNING :: points in grid of z-coordinates to similar
# 11:42:37.127 WARNING :: points in grid of z-coordinates to similar
# 11:42:37.127 WARNING :: points in grid of z-coordinates to similar
# 11:42:37.128 WARNING :: points in grid of z-coordinates to similar
# 11:42:37.154 WARNING :: points in grid of z-coordinates to similar
# 11:42:37.155 WARNING :: points in grid of z-coordinates to similar
# 11:42:37.155 WARNING :: points in grid of z-coordinates to similar
# 11:42:37.156 WARNING :: points in grid of z-coordinates to similar
# 11:42:37.156 WARNING :: points in grid of z-coordinates to similar
# 11:42:37.185 WARNING :: points in grid of z-coordinates to similar
# 11:42:37.186 WARNING :: points in grid of z-coordinates to similar
# 11:42:37.186 WARNING :: points in grid of z-coordinates to similar
# 11:42:37.186 WARNING :: points in grid of z-coordinates to similar
# 11:42:37.213 WARNING :: points in grid of z-coordinates to similar
# 11:42:37.214 WARNING :: points in grid of z-coordinates to similar
# 11:42:37.215 WARNING :: points in grid of z-coordinates to similar
# 11:42:37.215 WARNING :: points in grid of z-coordinates to similar
# 11:42:37.216 WARNING :: points in grid of z-coordinates to similar
# 11:42:37.286 WARNING :: points in grid of z-coordinates to similar
# 11:42:37.286 WARNING :: points in grid of z-coordinates to similar
# 11:42:37.287 WARNING :: points in grid of z-coordinates to similar
# 11:42:37.287 WARNING :: points in grid of z-coordinates to similar
# 11:42:37.288 WARNING :: points in grid of z-coordinates to similar
# 11:42:37.317 WARNING :: points in grid of z-coordinates to similar
# 11:42:37.317 WARNING :: points in grid of z-coordinates to similar
# 11:42:37.318 WARNING :: points in grid of z-coordinates to similar
# 11:42:37.318 WARNING :: points in grid of z-coordinates to similar
# 11:42:37.318 WARNING :: points in grid of z-coordinates to similar
# 11:42:37.348 WARNING :: points in grid of z-coordinates to similar
# 11:42:37.348 WARNING :: points in grid of z-coordinates to similar
# 11:42:37.349 WARNING :: points in grid of z-coordinates to similar
# 11:42:37.350 WARNING :: points in grid of z-coordinates to similar
# 11:42:37.375 WARNING :: points in grid of z-coordinates to similar
# 11:42:37.376 WARNING :: points in grid of z-coordinates to similar
# 11:42:37.377 WARNING :: points in grid of z-coordinates to similar
# 11:42:37.377 WARNING :: points in grid of z-coordinates to similar
# 11:42:37.378 WARNING :: points in grid of z-coordinates to similar
# 11:42:37.408 WARNING :: points in grid of z-coordinates to similar
# 11:42:37.409 WARNING :: points in grid of z-coordinates to similar
# 11:42:37.409 WARNING :: points in grid of z-coordinates to similar
# 11:42:37.410 WARNING :: points in grid of z-coordinates to similar
# 11:42:37.436 WARNING :: points in grid of z-coordinates to similar
# 11:42:37.437 WARNING :: points in grid of z-coordinates to similar
# 11:42:37.437 WARNING :: points in grid of z-coordinates to similar
# 11:42:37.438 WARNING :: points in grid of z-coordinates to similar
# 11:42:37.438 WARNING :: points in grid of z-coordinates to similar
# 11:42:37.507 WARNING :: points in grid of z-coordinates to similar
# 11:42:37.507 WARNING :: points in grid of z-coordinates to similar
# 11:42:37.508 WARNING :: points in grid of z-coordinates to similar
# 11:42:37.508 WARNING :: points in grid of z-coordinates to similar
# 11:42:37.508 WARNING :: points in grid of z-coordinates to similar
# 11:42:37.535 WARNING :: points in grid of z-coordinates to similar
# 11:42:37.536 WARNING :: points in grid of z-coordinates to similar
# 11:42:37.536 WARNING :: points in grid of z-coordinates to similar
# 11:42:37.537 WARNING :: points in grid of z-coordinates to similar
# 11:42:37.537 WARNING :: points in grid of z-coordinates to similar
# 11:42:37.565 WARNING :: points in grid of z-coordinates to similar
# 11:42:37.566 WARNING :: points in grid of z-coordinates to similar
# 11:42:37.566 WARNING :: points in grid of z-coordinates to similar
# 11:42:37.566 WARNING :: points in grid of z-coordinates to similar
# 11:42:37.567 WARNING :: points in grid of z-coordinates to similar
# 11:42:37.594 WARNING :: points in grid of z-coordinates to similar
# 11:42:37.594 WARNING :: points in grid of z-coordinates to similar
# 11:42:37.595 WARNING :: points in grid of z-coordinates to similar
# 11:42:37.595 WARNING :: points in grid of z-coordinates to similar
# 11:42:37.596 WARNING :: points in grid of z-coordinates to similar
# 11:42:37.626 WARNING :: points in grid of z-coordinates to similar
# 11:42:37.626 WARNING :: points in grid of z-coordinates to similar
# 11:42:37.627 WARNING :: points in grid of z-coordinates to similar
# 11:42:37.627 WARNING :: points in grid of z-coordinates to similar
# 11:42:37.627 WARNING :: points in grid of z-coordinates to similar
# 11:42:37.655 WARNING :: points in grid of z-coordinates to similar
# 11:42:37.656 WARNING :: points in grid of z-coordinates to similar
# 11:42:37.656 WARNING :: points in grid of z-coordinates to similar
# 11:42:37.656 WARNING :: points in grid of z-coordinates to similar
# 11:42:37.657 WARNING :: points in grid of z-coordinates to similar
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-6685719ad66c> in <module>
# ----> 1 picture_plot.plot_images(models, crosses=True, contour_lines=True, cross_width=0.05, contour_line_level=2)
#
# ~/Documents/git/contour-maps-visualization/contour_visualization/picture_plot.py in plot_images(distributions, plot_titles, titles, colors, columns, bottom, left, right, top, *args, **kwargs)
#      50                 if plot_titles:
#      51                     title = _generate_title(titles, distributions[i * columns], i * columns)
# ---> 52                 plot_image(ax[i * columns], distributions[i * columns], title=title, legend=True,
#      53                            legend_colors=color_legend, *args,
#      54                            **kwargs)
#
# TypeError: 'AxesSubplot' object does not support indexing
