# %%
import warnings; warnings.simplefilter('ignore')

# %%
from contour_visualization import picture_plot, MixtureModel

# %%
import pickle
import matplotlib.pyplot as plt

# %%
import logging

# %%
width = 9.5
height = 9.5
plt.rcParams['figure.figsize'] = [width, height]

# %%
# %load_ext autoreload
# %autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
logger = logging.getLogger("contour_visualization.picture_cross")
logger.setLevel(logging.INFO)

# %%
picture_plot.plot_images(dists, crosses=True, contour_lines=True, cross_width=0.005, contour_line_level=2)
# Out:
# 11:43:56.244 WARNING :: points in grid of z-coordinates to similar
# 11:43:56.371 WARNING :: points in grid of z-coordinates to similar

# %%
model_test = pickle.load(open("../../fitted_models/mcg_mpg_map.mdl", "rb"))

# %%
model_test.data.columns
# Out:
# Index(['transmission', 'cylinder', 'car_size', 'year', 'mpg_city',
#        'mpg_highway', 'displacement'],
#       dtype='object')

# %%
model_test.data
# Out:
#       transmission cylinder car_size  year  mpg_city  mpg_highway  \
# 250        lock-up      few  midsize  1995      18.0         24.0
# 251         manual      few    small  1999      21.0         29.0
# 252         manual      few  midsize  2001      19.0         27.0
# 253        lock-up      few    small  1996      25.0         31.0
# 254         manual      few    small  1988      33.0         39.0
# ...            ...      ...      ...   ...       ...          ...
# 23532      lock-up      few    small  1997      23.0         31.0
# 23533       manual      few  midsize  2007      17.0         23.0
# 23534       manual      few    large  1989      19.0         22.0
# 23535       manual      few    large  1985      17.0         19.0
# 23536         auto   medium  midsize  2001      13.0         16.0
#
#        displacement
# 250          2.3452
# 251          2.0000
# 252          2.0000
# 253          1.3284
# 254          1.3284
# ...             ...
# 23532        1.9844
# 23533        2.3000
# 23534        2.2632
# 23535        2.4600
# 23536        5.5000
#
# [23287 rows x 7 columns]

# %%
model_cit_high = MixtureModel.MixtureModel(model_test.data[["mpg_city", "mpg_highway"]])

# %%
model_dis_cit = MixtureModel.MixtureModel(model_test.data[["displacement", "mpg_city"]])

# %%
model_dis_high = MixtureModel.MixtureModel(model_test.data[["displacement", "mpg_highway"]])

# %%
dists = [model_cit_high.get_gaussians(), model_dis_cit.get_gaussians(), model_dis_high.get_gaussians()]
# Out:
# 11:07:46.449 INFO :: Means[0]: [0.27882061 0.28885445]
# 11:07:46.450 INFO :: Cov-Matrix[0]: [[0.00342819 0.0030972 ]
#  [0.0030972  0.00382949]]
# 11:07:46.451 INFO :: weights[0]: 0.5016011016182549
# 11:07:46.452 INFO :: Means[1]: [0.38703093 0.36475431]
# 11:07:46.453 INFO :: Cov-Matrix[1]: [[0.01861805 0.01617742]
#  [0.01617742 0.01636989]]
# 11:07:46.453 INFO :: weights[1]: 0.1739832164798523
# 11:07:46.454 INFO :: Means[2]: [0.18302925 0.15264898]
# 11:07:46.454 INFO :: Cov-Matrix[2]: [[0.00329487 0.00281249]
#  [0.00281249 0.00313126]]
# 11:07:46.455 INFO :: weights[2]: 0.324415681901939
# 11:07:46.456 INFO :: Means[0]: [0.24597522 0.35902961]
# 11:07:46.456 INFO :: Cov-Matrix[0]: [[ 0.00243874 -0.0035159 ]
#  [-0.0035159   0.01075641]]
# 11:07:46.457 INFO :: weights[0]: 0.3577411425848611
# 11:07:46.458 INFO :: Means[1]: [0.39680617 0.24245591]
# 11:07:46.459 INFO :: Cov-Matrix[1]: [[ 0.00939484 -0.00276979]
#  [-0.00276979  0.00148904]]
# 11:07:46.459 INFO :: weights[1]: 0.4334182894160095
# 11:07:46.460 INFO :: Means[2]: [0.63023766 0.1582388 ]
# 11:07:46.461 INFO :: Cov-Matrix[2]: [[ 0.0068661  -0.00110169]
#  [-0.00110169  0.0030512 ]]
# 11:07:46.461 INFO :: weights[2]: 0.20884056799914064
# 11:07:46.462 INFO :: Means[0]: [0.33982761 0.27138431]
# 11:07:46.463 INFO :: Cov-Matrix[0]: [[ 0.00547878 -0.00116224]
#  [-0.00116224  0.00270197]]
# 11:07:46.463 INFO :: weights[0]: 0.3523713848691355
# 11:07:46.464 INFO :: Means[1]: [0.57613938 0.15942291]
# 11:07:46.465 INFO :: Cov-Matrix[1]: [[ 0.01052564 -0.00237205]
#  [-0.00237205  0.00400727]]
# 11:07:46.465 INFO :: weights[1]: 0.34644213055918915
# 11:07:46.466 INFO :: Means[2]: [0.2398953  0.35530707]
# 11:07:46.467 INFO :: Cov-Matrix[2]: [[ 0.00205291 -0.00301869]
#  [-0.00301869  0.01070392]]
# 11:07:46.468 INFO :: weights[2]: 0.301186484571676

# %%
picture_plot.plot_images([dists[0],], contours=True)

# %%
picture_plot.plot_images([dists[1],], contours=True)

# %%
picture_plot.plot_images([dists[2],], contours=True, contour_lines=True, contour_line_level=1)

# %%
picture_plot.plot_images(dists, contours=True, contour_lines=True, contour_line_level=1)

# %%
picture_plot.plot_images(dists, pie_charts=True, pie_num=25)
