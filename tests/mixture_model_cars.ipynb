# %%
from contour_visualization import picture_plot, MixtureModel
# Out:
# 11:33:55.938 WARNING :: Using NumPy C-API based implementation for BLAS functions.

# %%
import pickle
import matplotlib.pyplot as plt

# %%
width = 9.5
height = 9.5
plt.rcParams['figure.figsize'] = [width, height]

# %%
# %load_ext autoreload
# %autoreload

# %%
model_test = pickle.load(open("../../fitted_models/mcg_mpg_map.mdl", "rb"))

# %%
model_test.data.columns
# Out:
# Index(['transmission', 'cylinder', 'car_size', 'year', 'mpg_city',
#        'mpg_highway', 'displacement'],
#       dtype='object')

# %%
model_test.data
# Out:
#       transmission cylinder car_size  year  mpg_city  mpg_highway  \
# 250        lock-up      few  midsize  1995      18.0         24.0
# 251         manual      few    small  1999      21.0         29.0
# 252         manual      few  midsize  2001      19.0         27.0
# 253        lock-up      few    small  1996      25.0         31.0
# 254         manual      few    small  1988      33.0         39.0
# ...            ...      ...      ...   ...       ...          ...
# 23532      lock-up      few    small  1997      23.0         31.0
# 23533       manual      few  midsize  2007      17.0         23.0
# 23534       manual      few    large  1989      19.0         22.0
# 23535       manual      few    large  1985      17.0         19.0
# 23536         auto   medium  midsize  2001      13.0         16.0
#
#        displacement
# 250          2.3452
# 251          2.0000
# 252          2.0000
# 253          1.3284
# 254          1.3284
# ...             ...
# 23532        1.9844
# 23533        2.3000
# 23534        2.2632
# 23535        2.4600
# 23536        5.5000
#
# [23287 rows x 7 columns]

# %%
model_cit_high = MixtureModel.MixtureModel(model_test.data[["mpg_city", "mpg_highway"]])

# %%
model_dis_cit = MixtureModel.MixtureModel(model_test.data[["displacement", "mpg_city"]])

# %%
model_dis_high = MixtureModel.MixtureModel(model_test.data[["displacement", "mpg_highway"]])

# %%
dists = [model_cit_high.get_gaussians(), model_dis_cit.get_gaussians(), model_dis_high.get_gaussians()]
# Out:
# 11:33:56.716 INFO :: Means[0]: [17.19985258 24.01765032]
# 11:33:56.717 INFO :: Cov-Matrix[0]: [[ 5.06554902  6.14012675]
#  [ 6.14012675 10.19884021]]
# 11:33:56.717 INFO :: weights[0]: 0.5058275969941162
# 11:33:56.718 INFO :: Means[1]: [21.70436588 28.09424981]
# 11:33:56.719 INFO :: Cov-Matrix[1]: [[28.20702826 29.72923158]
#  [29.72923158 36.79826834]]
# 11:33:56.719 INFO :: weights[1]: 0.22954359575819985
# 11:33:56.720 INFO :: Means[2]: [13.27796065 17.20846425]
# 11:33:56.721 INFO :: Cov-Matrix[2]: [[5.46566507 5.35379368]
#  [5.35379368 7.06076897]]
# 11:33:56.721 INFO :: weights[2]: 0.26462880724766663
# 11:33:56.722 INFO :: Means[0]: [ 2.31680435 19.04777487]
# 11:33:56.723 INFO :: Cov-Matrix[0]: [[ 0.20954073 -0.94815738]
#  [-0.94815738  7.32068564]]
# 11:33:56.724 INFO :: weights[0]: 0.4369295923785396
# 11:33:56.724 INFO :: Means[1]: [ 4.3522123 14.405597 ]
# 11:33:56.725 INFO :: Cov-Matrix[1]: [[ 1.18715643 -1.82680626]
#  [-1.82680626  5.95769804]]
# 11:33:56.726 INFO :: weights[1]: 0.4965470344684771
# 11:33:56.726 INFO :: Means[2]: [ 1.74468302 25.86152984]
# 11:33:56.727 INFO :: Cov-Matrix[2]: [[ 0.1701559  -1.50895581]
#  [-1.50895581 40.50476311]]
# 11:33:56.728 INFO :: weights[2]: 0.06652337315298881
# 11:33:56.729 INFO :: Means[0]: [ 3.40806056 23.16946631]
# 11:33:56.730 INFO :: Cov-Matrix[0]: [[ 1.08263741 -1.149809  ]
#  [-1.149809    7.07141526]]
# 11:33:56.730 INFO :: weights[0]: 0.3560839646020199
# 11:33:56.731 INFO :: Means[1]: [ 2.15272731 27.0891638 ]
# 11:33:56.732 INFO :: Cov-Matrix[1]: [[ 0.19721301 -1.57298102]
#  [-1.57298102 26.95619699]]
# 11:33:56.733 INFO :: weights[1]: 0.396607667956116
# 11:33:56.734 INFO :: Means[2]: [ 4.94151018 16.81081549]
# 11:33:56.738 INFO :: Cov-Matrix[2]: [[ 0.6837434  -0.92124536]
#  [-0.92124536  6.09220977]]
# 11:33:56.739 INFO :: weights[2]: 0.2473083674418494

# %%
picture_plot.plot_images([dists[0],], contours=True)

# %%
picture_plot.plot_images([dists[1],], contours=True)

# %%
picture_plot.plot_images([dists[2],], contours=True, contour_lines=True, contour_line_level=1)

# %%
picture_plot.plot_images(dists, contours=True, contour_lines=True, contour_line_level=1)

# %%
picture_plot.plot_images(dists, pie_charts=True, pie_num=25)

# %%
picture_plot.plot_images(dists, crosses=True, contour_lines=True, cross_width=0.1, contour_line_level=2)
# Out:
# 11:36:58.765 WARNING :: points in grid of z-coordinates to similar
# 11:36:58.765 WARNING :: points in grid of z-coordinates to similar
# 11:36:58.766 WARNING :: points in grid of z-coordinates to similar
# 11:36:58.826 WARNING :: points in grid of z-coordinates to similar
# 11:36:58.881 WARNING :: points in grid of z-coordinates to similar
# 11:36:58.881 WARNING :: points in grid of z-coordinates to similar
# 11:36:58.881 WARNING :: points in grid of z-coordinates to similar
# 11:36:58.999 WARNING :: points in grid of z-coordinates to similar
# 11:36:59.000 WARNING :: points in grid of z-coordinates to similar
# 11:36:59.000 WARNING :: points in grid of z-coordinates to similar
# 11:36:59.000 WARNING :: points in grid of z-coordinates to similar
# 11:36:59.001 WARNING :: points in grid of z-coordinates to similar
# 11:36:59.053 WARNING :: points in grid of z-coordinates to similar
# 11:36:59.054 WARNING :: points in grid of z-coordinates to similar
# 11:36:59.054 WARNING :: points in grid of z-coordinates to similar
# 11:36:59.055 WARNING :: points in grid of z-coordinates to similar
# 11:36:59.107 WARNING :: points in grid of z-coordinates to similar
# 11:36:59.107 WARNING :: points in grid of z-coordinates to similar
# 11:36:59.108 WARNING :: points in grid of z-coordinates to similar
# 11:36:59.108 WARNING :: points in grid of z-coordinates to similar
# 11:36:59.109 WARNING :: points in grid of z-coordinates to similar
# 11:36:59.211 WARNING :: points in grid of z-coordinates to similar
# 11:36:59.212 WARNING :: points in grid of z-coordinates to similar
# 11:36:59.212 WARNING :: points in grid of z-coordinates to similar
# 11:36:59.265 WARNING :: points in grid of z-coordinates to similar
# 11:36:59.265 WARNING :: points in grid of z-coordinates to similar
# 11:36:59.266 WARNING :: points in grid of z-coordinates to similar
# 11:36:59.266 WARNING :: points in grid of z-coordinates to similar
# 11:36:59.267 WARNING :: points in grid of z-coordinates to similar
# 11:36:59.318 WARNING :: points in grid of z-coordinates to similar
# 11:36:59.319 WARNING :: points in grid of z-coordinates to similar
# 11:36:59.319 WARNING :: points in grid of z-coordinates to similar
# 11:36:59.320 WARNING :: points in grid of z-coordinates to similar
