# %%
from matplotlib import pyplot as plt
from numpy.random import randn
# %matplotlib inline
import numpy as np

import color_blending_operator
import color_converter
import color_operations
import color_schemes
import picture_worker
import helper

# %%
x_min, x_max = -10, 10
y_min, y_max = -10, 10
size = 200

mu_x_1 = 0
mu_y_1 = 0
mu_variance_x_1 = 3
mu_variance_y_1 = 15
gaussian_1 = (mu_x_1,mu_variance_x_1,mu_y_1,mu_variance_y_1)
mu_x_2 = 3
mu_y_2 = 3
mu_variance_x_2 = 4
mu_variance_y_2 = 4
gaussian_2 = (mu_x_2,mu_variance_x_2,mu_y_2,mu_variance_y_2)
mu_x_3 = -2
mu_y_3 = -1
mu_variance_x_3 = 7
mu_variance_y_3 = 7
gaussian_3 = (mu_x_3,mu_variance_x_3,mu_y_3,mu_variance_y_3)

# %%
X, Y, Z = helper.get_gaussian(x_min,x_max,y_min,y_max,*gaussian_1,size)
X_1, Y_1, Z_1 = helper.get_gaussian(x_min,x_max,y_min,y_max,*gaussian_2,size)
X_2, Y_2, Z_2 = helper.get_gaussian(x_min,x_max,y_min,y_max,*gaussian_3,size)

# %%
levels = 10
fig, (ax_0, ax_1, ax_2, ax_3) = plt.subplots(1,4)
ax_0.contourf(X, Y, Z, levels, cmap="PuBu", extend='both')
ax_0.axis("off")
ax_1.contourf(X_1, Y_1, Z_1, levels, cmap="OrRd", extend='both')
ax_1.axis("off")
ax_2.contourf(X_2, Y_2, Z_2, levels, cmap="RdPu", extend='both')
ax_2.axis("off")
ax_3.contourf(X, Y, Z, levels, cmap="PuBu", extend='both')
ax_3.contourf(X_1, Y_1, Z_1, levels, cmap="OrRd", extend='both', alpha = 0.5)
ax_3.contourf(X_2, Y_2, Z_2, levels, cmap="RdPu", extend='both', alpha = 0.5)
ax_3.scatter([-5,5],[-5,5],color="b")
#plt.draw()
#ax_3.axis("off")
plt.show()
# Out:
# <matplotlib.backends._backend_agg.RendererAgg object at 0x7f2df0d13090>
# <matplotlib.backend_bases.GraphicsContextBase object at 0x7f2dee59e2b0>
# _______
# Affine2D(
#     [[  3.63913043   0.          90.39130435]
#      [  0.          10.872      144.72      ]
#      [  0.           0.           1.        ]])
# _______
# get_transforms: []
# _______
# offsets: [[0. 0.]]
# _______
# transOffset: IdentityTransform()
# _______
# get_facecolor: [[1.         0.96862745 0.98431373 1.        ]]
# _______
# get_edgecolor: []
# _______
# _antialiaseds: [False]
# _______
# _______
# _______
# <matplotlib.backend_bases.GraphicsContextBase object at 0x7f2dee59e2b0>
# _______
# Affine2D(
#     [[  3.63913043   0.          90.39130435]
#      [  0.          10.872      144.72      ]
#      [  0.           0.           1.        ]])
# _______
# get_transforms: []
# _______
# offsets: [[0. 0.]]
# _______
# transOffset: IdentityTransform()
# _______
# get_facecolor: [[0.96493656 0.93910035 0.96770473 1.        ]]
# _______
# get_edgecolor: []
# _______
# _antialiaseds: [False]
# _______
# _______
# _______
# <matplotlib.backend_bases.GraphicsContextBase object at 0x7f2dee59e2b0>
# _______
# Affine2D(
#     [[  3.63913043   0.          90.39130435]
#      [  0.          10.872      144.72      ]
#      [  0.           0.           1.        ]])
# _______
# get_transforms: []
# _______
# offsets: [[0. 0.]]
# _______
# transOffset: IdentityTransform()
# _______
# get_facecolor: [[0.86994233 0.8622376  0.92521338 1.        ]]
# _______
# get_edgecolor: []
# _______
# _antialiaseds: [False]
# _______
# _______
# _______
# <matplotlib.backend_bases.GraphicsContextBase object at 0x7f2dee59e2b0>
# _______
# Affine2D(
#     [[  3.63913043   0.          90.39130435]
#      [  0.          10.872      144.72      ]
#      [  0.           0.           1.        ]])
# _______
# get_transforms: []
# _______
# offsets: [[0. 0.]]
# _______
# transOffset: IdentityTransform()
# _______
# get_facecolor: [[0.73171857 0.77962322 0.87996924 1.        ]]
# _______
# get_edgecolor: []
# _______
# _antialiaseds: [False]
# _______
# _______
# _______
# <matplotlib.backend_bases.GraphicsContextBase object at 0x7f2dee59e2b0>
# _______
# Affine2D(
#     [[  3.63913043   0.          90.39130435]
#      [  0.          10.872      144.72      ]
#      [  0.           0.           1.        ]])
# _______
# get_transforms: []
# _______
# offsets: [[0. 0.]]
# _______
# transOffset: IdentityTransform()
# _______
# get_facecolor: [[0.55640138 0.70334487 0.83612457 1.        ]]
# _______
# get_edgecolor: []
# _______
# _antialiaseds: [False]
# _______
# _______
# _______
# <matplotlib.backend_bases.GraphicsContextBase object at 0x7f2dee59e2b0>
# _______
# Affine2D(
#     [[  3.63913043   0.          90.39130435]
#      [  0.          10.872      144.72      ]
#      [  0.           0.           1.        ]])
# _______
# get_transforms: []
# _______
# offsets: [[0. 0.]]
# _______
# transOffset: IdentityTransform()
# _______
# get_facecolor: [[0.32904268 0.61199539 0.78131488 1.        ]]
# _______
# get_edgecolor: []
# _______
# _antialiaseds: [False]
# _______
# _______
# _______
# <matplotlib.backend_bases.GraphicsContextBase object at 0x7f2dee59e2b0>
# _______
# Affine2D(
#     [[  3.63913043   0.          90.39130435]
#      [  0.          10.872      144.72      ]
#      [  0.           0.           1.        ]])
# _______
# get_transforms: []
# _______
# offsets: [[0. 0.]]
# _______
# transOffset: IdentityTransform()
# _______
# get_facecolor: [[0.11154171 0.49925413 0.7202153  1.        ]]
# _______
# get_edgecolor: []
# _______
# _antialiaseds: [False]
# _______
# _______
# _______
# <matplotlib.backend_bases.GraphicsContextBase object at 0x7f2dee59e2b0>
# _______
# Affine2D(
#     [[  3.63913043   0.          90.39130435]
#      [  0.          10.872      144.72      ]
#      [  0.           0.           1.        ]])
# _______
# get_transforms: []
# _______
# offsets: [[0. 0.]]
# _______
# transOffset: IdentityTransform()
# _______
# get_facecolor: [[0.0175471  0.39387928 0.61806997 1.        ]]
# _______
# get_edgecolor: []
# _______
# _antialiaseds: [False]
# _______
# _______
# _______
# <matplotlib.backend_bases.GraphicsContextBase object at 0x7f2dee59e2b0>
# _______
# Affine2D(
#     [[  3.63913043   0.          90.39130435]
#      [  0.          10.872      144.72      ]
#      [  0.           0.           1.        ]])
# _______
# get_transforms: []
# _______
# offsets: [[0. 0.]]
# _______
# transOffset: IdentityTransform()
# _______
# get_facecolor: [[0.01153403 0.28235294 0.44290657 1.        ]]
# _______
# get_edgecolor: []
# _______
# _antialiaseds: [False]
# _______
# _______
# _______
# <matplotlib.backend_bases.GraphicsContextBase object at 0x7f2dee59e2b0>
# _______
# Affine2D(
#     [[  3.63913043   0.          90.39130435]
#      [  0.          10.872      144.72      ]
#      [  0.           0.           1.        ]])
# _______
# get_transforms: []
# _______
# offsets: [[0. 0.]]
# _______
# transOffset: IdentityTransform()
# _______
# get_facecolor: [[0.00784314 0.21960784 0.34509804 1.        ]]
# _______
# get_edgecolor: []
# _______
# _antialiaseds: [False]
# _______
# _______
# _______
# <matplotlib.backend_bases.GraphicsContextBase object at 0x7f2dee59ef28>
# _______
# Affine2D(
#     [[  3.63913043   0.         177.73043478]
#      [  0.          10.872      144.72      ]
#      [  0.           0.           1.        ]])
# _______
# get_transforms: []
# _______
# offsets: [[0. 0.]]
# _______
# transOffset: IdentityTransform()
# _______
# get_facecolor: [[1.         0.96862745 0.9254902  1.        ]]
# _______
# get_edgecolor: []
# _______
# _antialiaseds: [False]
# _______
# _______
# _______
# <matplotlib.backend_bases.GraphicsContextBase object at 0x7f2dee59ef28>
# _______
# Affine2D(
#     [[  3.63913043   0.         177.73043478]
#      [  0.          10.872      144.72      ]
#      [  0.           0.           1.        ]])
# _______
# get_transforms: []
# _______
# offsets: [[0. 0.]]
# _______
# transOffset: IdentityTransform()
# _______
# get_facecolor: [[0.99803153 0.93910035 0.85462514 1.        ]]
# _______
# get_edgecolor: []
# _______
# _antialiaseds: [False]
# _______
# _______
# _______
# <matplotlib.backend_bases.GraphicsContextBase object at 0x7f2dee59ef28>
# _______
# Affine2D(
#     [[  3.63913043   0.         177.73043478]
#      [  0.          10.872      144.72      ]
#      [  0.           0.           1.        ]])
# _______
# get_transforms: []
# _______
# offsets: [[0. 0.]]
# _______
# transOffset: IdentityTransform()
# _______
# get_facecolor: [[0.99409458 0.87012687 0.70099193 1.        ]]
# _______
# get_edgecolor: []
# _______
# _antialiaseds: [False]
# _______
# _______
# _______
# <matplotlib.backend_bases.GraphicsContextBase object at 0x7f2dee59ef28>
# _______
# Affine2D(
#     [[  3.63913043   0.         177.73043478]
#      [  0.          10.872      144.72      ]
#      [  0.           0.           1.        ]])
# _______
# get_transforms: []
# _______
# offsets: [[0. 0.]]
# _______
# transOffset: IdentityTransform()
# _______
# get_facecolor: [[0.99215686 0.78139177 0.56762784 1.        ]]
# _______
# get_edgecolor: []
# _______
# _antialiaseds: [False]
# _______
# _______
# _______
# <matplotlib.backend_bases.GraphicsContextBase object at 0x7f2dee59ef28>
# _______
# Affine2D(
#     [[  3.63913043   0.         177.73043478]
#      [  0.          10.872      144.72      ]
#      [  0.           0.           1.        ]])
# _______
# get_transforms: []
# _______
# offsets: [[0. 0.]]
# _______
# transOffset: IdentityTransform()
# _______
# get_facecolor: [[0.99014225 0.64066128 0.43101884 1.        ]]
# _______
# get_edgecolor: []
# _______
# _antialiaseds: [False]
# _______
# _______
# _______
# <matplotlib.backend_bases.GraphicsContextBase object at 0x7f2dee59ef28>
# _______
# Affine2D(
#     [[  3.63913043   0.         177.73043478]
#      [  0.          10.872      144.72      ]
#      [  0.           0.           1.        ]])
# _______
# get_transforms: []
# _______
# offsets: [[0. 0.]]
# _______
# transOffset: IdentityTransform()
# _______
# get_facecolor: [[0.96184544 0.47174164 0.3145098  1.        ]]
# _______
# get_edgecolor: []
# _______
# _antialiaseds: [False]
# _______
# _______
# _______
# <matplotlib.backend_bases.GraphicsContextBase object at 0x7f2dee
0.5       ]]
# _______
# get_edgecolor: []
# _______
# _antialiaseds: [False]
# _______
# _______
# _______
# <matplotlib.backend_bases.GraphicsContextBase object at 0x7f2dee5c59b0>
# _______
# Affine2D(
#     [[  3.63913043   0.         343.10869565]
#      [  0.          10.872      132.92      ]
#      [  0.           0.           1.        ]])
# _______
# get_transforms: []
# _______
# offsets: [[0. 0.]]
# _______
# transOffset: IdentityTransform()
# _______
# get_facecolor: [[0.28627451 0.         0.41568627 0.5       ]]
# _______
# get_edgecolor: []
# _______
# _antialiaseds: [False]
# _______
# _______
# _______

# %%
fig, (ax_0, ax_1) = plt.subplots(1,2)
#ax_0.contourf(X_1, Y_1, Z_1, levels, cmap="OrRd", extend='both')
ax_1.contourf(X_1, Y_1, Z_1, levels, cmap="OrRd", extend='both', alpha=0.5)
plt.show()
# Out:
# <matplotlib.backends._backend_agg.RendererAgg object at 0x7f2df0d131b0>
# <matplotlib.backend_bases.GraphicsContextBase object at 0x7f2dee4fdda0>
# _______
# Affine2D(
#     [[  7.60909091   0.         312.70909091]
#      [  0.          10.872      144.72      ]
#      [  0.           0.           1.        ]])
# _______
# get_transforms: []
# _______
# offsets: [[0. 0.]]
# _______
# transOffset: IdentityTransform()
# _______
# get_facecolor: [[1.         0.96862745 0.9254902  0.5       ]]
# _______
# get_edgecolor: []
# _______
# _antialiaseds: [False]
# _______
# _______
# _______
# <matplotlib.backend_bases.GraphicsContextBase object at 0x7f2dee4fdda0>
# _______
# Affine2D(
#     [[  7.60909091   0.         312.70909091]
#      [  0.          10.872      144.72      ]
#      [  0.           0.           1.        ]])
# _______
# get_transforms: []
# _______
# offsets: [[0. 0.]]
# _______
# transOffset: IdentityTransform()
# _______
# get_facecolor: [[0.99803153 0.93910035 0.85462514 0.5       ]]
# _______
# get_edgecolor: []
# _______
# _antialiaseds: [False]
# _______
# _______
# _______
# <matplotlib.backend_bases.GraphicsContextBase object at 0x7f2dee4fdda0>
# _______
# Affine2D(
#     [[  7.60909091   0.         312.70909091]
#      [  0.          10.872      144.72      ]
#      [  0.           0.           1.        ]])
# _______
# get_transforms: []
# _______
# offsets: [[0. 0.]]
# _______
# transOffset: IdentityTransform()
# _______
# get_facecolor: [[0.99409458 0.87012687 0.70099193 0.5       ]]
# _______
# get_edgecolor: []
# _______
# _antialiaseds: [False]
# _______
# _______
# _______
# <matplotlib.backend_bases.GraphicsContextBase object at 0x7f2dee4fdda0>
# _______
# Affine2D(
#     [[  7.60909091   0.         312.70909091]
#      [  0.          10.872      144.72      ]
#      [  0.           0.           1.        ]])
# _______
# get_transforms: []
# _______
# offsets: [[0. 0.]]
# _______
# transOffset: IdentityTransform()
# _______
# get_facecolor: [[0.99215686 0.78139177 0.56762784 0.5       ]]
# _______
# get_edgecolor: []
# _______
# _antialiaseds: [False]
# _______
# _______
# _______
# <matplotlib.backend_bases.GraphicsContextBase object at 0x7f2dee4fdda0>
# _______
# Affine2D(
#     [[  7.60909091   0.         312.70909091]
#      [  0.          10.872      144.72      ]
#      [  0.           0.           1.        ]])
# _______
# get_transforms: []
# _______
# offsets: [[0. 0.]]
# _______
# transOffset: IdentityTransform()
# _______
# get_facecolor: [[0.99014225 0.64066128 0.43101884 0.5       ]]
# _______
# get_edgecolor: []
# _______
# _antialiaseds: [False]
# _______
# _______
# _______
# <matplotlib.backend_bases.GraphicsContextBase object at 0x7f2dee4fdda0>
# _______
# Affine2D(
#     [[  7.60909091   0.         312.70909091]
#      [  0.          10.872      144.72      ]
#      [  0.           0.           1.        ]])
# _______
# get_transforms: []
# _______
# offsets: [[0. 0.]]
# _______
# transOffset: IdentityTransform()
# _______
# get_facecolor: [[0.96184544 0.47174164 0.3145098  0.5       ]]
# _______
# get_edgecolor: []
# _______
# _antialiaseds: [False]
# _______
# _______
# _______
# <matplotlib.backend_bases.GraphicsContextBase object at 0x7f2dee4fdda0>
# _______
# Affine2D(
#     [[  7.60909091   0.         312.70909091]
#      [  0.          10.872      144.72      ]
#      [  0.           0.           1.        ]])
# _______
# get_transforms: []
# _______
# offsets: [[0. 0.]]
# _______
# transOffset: IdentityTransform()
# _______
# get_facecolor: [[0.88816609 0.28767397 0.19849289 0.5       ]]
# _______
# get_edgecolor: []
# _______
# _antialiaseds: [False]
# _______
# _______
# _______
# <matplotlib.backend_bases.GraphicsContextBase object at 0x7f2dee4fdda0>
# _______
# Affine2D(
#     [[  7.60909091   0.         312.70909091]
#      [  0.          10.872      144.72      ]
#      [  0.           0.           1.        ]])
# _______
# get_transforms: []
# _______
# offsets: [[0. 0.]]
# _______
# transOffset: IdentityTransform()
# _______
# get_facecolor: [[0.7689504  0.08931949 0.05768551 0.5       ]]
# _______
# get_edgecolor: []
# _______
# _antialiaseds: [False]
# _______
# _______
# _______
# <matplotlib.backend_bases.GraphicsContextBase object at 0x7f2dee4fdda0>
# _______
# Affine2D(
#     [[  7.60909091   0.         312.70909091]
#      [  0.          10.872      144.72      ]
#      [  0.           0.           1.        ]])
# _______
# get_transforms: []
# _______
# offsets: [[0. 0.]]
# _______
# transOffset: IdentityTransform()
# _______
# get_facecolor: [[0.59400231 0.         0.         0.5       ]]
# _______
# get_edgecolor: []
# _______
# _antialiaseds: [False]
# _______
# _______
# _______
# <matplotlib.backend_bases.GraphicsContextBase object at 0x7f2dee4fdda0>
# _______
# Affine2D(
#     [[  7.60909091   0.         312.70909091]
#      [  0.          10.872      144.72      ]
#      [  0.           0.           1.        ]])
# _______
# get_transforms: []
# _______
# offsets: [[0. 0.]]
# _______
# transOffset: IdentityTransform()
# _______
# get_facecolor: [[0.49803922 0.         0.         0.5       ]]
# _______
# get_edgecolor: []
# _______
# _antialiaseds: [False]
# _______
# _______
# _______
# <matplotlib.backends._backend_agg.RendererAgg object at 0x7f2df0d130f0>
# <matplotlib.backend_bases.GraphicsContextBase object at 0x7f2dee4c37b8>
# _______
# Affine2D(
#     [[  7.60909091   0.         288.78409091]
#      [  0.          10.872      132.92      ]
#      [  0.           0.           1.        ]])
# _______
# get_transforms: []
# _______
# offsets: [[0. 0.]]
# _______
# transOffset: IdentityTransform()
# _______
# get_facecolor: [[1.         0.96862745 0.9254902  0.5       ]]
# _______
# get_edgecolor: []
# _______
# _antialiaseds: [False]
# _______
# _______
# _______
# <matplotlib.backend_bases.GraphicsContextBase object at 0x7f2dee504b38>
# _______
# Affine2D(
#     [[  7.60909091   0.         288.78409091]
#      [  0.          10.872      132.92      ]
#      [  0.           0.           1.        ]])
# _______
# get_transforms: []
# _______
# offsets: [[0. 0.]]
# _______
# transOffset: IdentityTransform()
# _______
# get_facecolor: [[0.99803153 0.93910035 0.85462514 0.5       ]]
# _______
# get_edgecolor: []
# _______
# _antialiaseds: [False]
# _______
# _______
# _______
# <matplotlib.backend_bases.GraphicsContextBase object at 0x7f2dee504b38>
# _______
# Affine2D(
#     [[  7.60909091   0.         288.78409091]
#      [  0.          10.872      132.92      ]
#      [  0.           0.           1.        ]])
# _______
# get_transforms: []
# _______
# offsets: [[0. 0.]]
# _______
# transOffset: IdentityTransform()
# _______
# get_facecolor: [[0.99409458 0.87012687 0.70099193 0.5       ]]
# _______
# get_edgecolor: []
# _______
# _antialiaseds: [False]
# _______
# _______
# _______
# <matplotlib.backend_bases.GraphicsContextBase object at 0x7f2dee504b38>
# _______
# Affine2D(
#     [[  7.60909091   0.         288.78409091]
#      [  0.          10.872      132.92      ]
#      [  0.           0.           1.        ]])
# _______
# get_transforms: []
# _______
# offsets: [[0. 0.]]
# _______
# transOffset: IdentityTransform()
# _______
# get_facecolor: [[0.99215686 0.78139177 0.56762784 0.5       ]]
# _______
# get_edgecolor: []
# _______
# _antialiaseds: [False]
# _______
# _______
# _______
# <matplotlib.backend_bases.GraphicsContextBase object at 0x7f2dee504b38>
# _______
# Affine2D(
#     [[  7.60909091   0.         288.78409091]
#      [  0.          10.872      132.92      ]
#      [  0.           0.           1.        ]])
# _______
# get_transforms: []
# _______
# offsets: [[0. 0.]]
# _______
# transOffset: IdentityTransform()
# _______
# get_facecolor: [[0.99014225 0.64066128 0.43101884 0.5       ]]
# _______
# get_edgecolor: []
# _______
# _antialiaseds: [False]
# _______
# _______
# _______
# <matplotlib.backend_bases.GraphicsContextBase object at 0x7f2dee504b38>
# _______
# Affine2D(
#     [[  7.60909091   0.         288.78409091]
#      [  0.          10.872      132.92      ]
#      [  0.           0.           1.        ]])
# _______
# get_transforms: []
# _______
# offsets: [[0. 0.]]
# _______
# transOffset: IdentityTransform()
# _______
# get_facecolor: [[0.96184544 0.47174164 0.3145098  0.5       ]]
# _______
# get_edgecolor: []
# _______
# _antialiaseds: [False]
# _______
# _______
# _______
# <matplotlib.backend_bases.GraphicsContextBase object at 0x7f2dee504b38>
# _______
# Affine2D(
#     [[  7.60909091   0.         288.78409091]
#      [  0.          10.872      132.92      ]
#      [  0.           0.           1.        ]])
# _______
# get_transforms: []
# _______
# offsets: [[0. 0.]]
# _______
# transOffset: IdentityTransform()
# _______
# get_facecolor: [[0.88816609 0.28767397 0.19849289 0.5       ]]
# _______
# get_edgecolor: []
# _______
# _antialiaseds: [False]
# _______
# _______
# _______
# <matplotlib.backend_bases.GraphicsContextBase object at 0x7f2dee504b38>
# _______
# Affine2D(
#     [[  7.60909091   0.         288.78409091]
#      [  0.          10.872      132.92      ]
#      [  0.           0.           1.        ]])
# _______
# get_transforms: []
# _______
# offsets: [[0. 0.]]
# _______
# transOffset: IdentityTransform()
# _______
# get_facecolor: [[0.7689504  0.08931949 0.05768551 0.5       ]]
# _______
# get_edgecolor: []
# _______
# _antialiaseds: [False]
# _______
# _______
# _______
# <matplotlib.backend_bases.GraphicsContextBase object at 0x7f2dee504b38>
# _______
# Affine2D(
#     [[  7.60909091   0.         288.78409091]
#      [  0.          10.872      132.92      ]
#      [  0.           0.           1.        ]])
# _______
# get_transforms: []
# _______
# offsets: [[0. 0.]]
# _______
# transOffset: IdentityTransform()
# _______
# get_facecolor: [[0.59400231 0.         0.         0.5       ]]
# _______
# get_edgecolor: []
# _______
# _antialiaseds: [False]
# _______
# _______
# _______
# <matplotlib.backend_bases.GraphicsContextBase object at 0x7f2dee504b38>
# _______
# Affine2D(
#     [[  7.60909091   0.         288.78409091]
#      [  0.          10.872      132.92      ]
#      [  0.           0.           1.        ]])
# _______
# get_transforms: []
# _______
# offsets: [[0. 0.]]
# _______
# transOffset: IdentityTransform()
# _______
# get_facecolor: [[0.49803922 0.         0.         0.5       ]]
# _______
# get_edgecolor: []
# _______
# _antialiaseds: [False]
# _______
# _______
# _______
