# %% [markdown]
# compare with matplotlib examples

# %%
# Libraries
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy.stats import kde

# %%
# Create data: 200 points
data = np.random.multivariate_normal([0, 0], [[1, 0.5], [0.5, 3]], 200)
x, y = data.T

# %%
# Create a figure with 6 plot areas
fig, axes = plt.subplots(ncols=6, nrows=1, figsize=(21, 5))

# Everything starts with a Scatterplot
# axes[0].set_title('Scatterplot')
# axes[0].plot(x, y, 'ko')

# Thus we can cut the plotting window in several hexbins
nbins = 20
# axes[1].set_title('Hexbin')
# axes[1].hexbin(x, y, gridsize=nbins, cmap=plt.cm.BuGn_r)

# 2D Histogram
# axes[2].set_title('2D Histogram')
# axes[2].hist2d(x, y, bins=nbins, cmap=plt.cm.BuGn_r)

# Evaluate a gaussian kde on a regular grid of nbins x nbins over data extents
k = kde.gaussian_kde(data.T)
xi, yi = np.mgrid[x.min():x.max():nbins * 1j, y.min():y.max():nbins * 1j]
zi = k(np.vstack([xi.flatten(), yi.flatten()]))

# plot a density
# axes[3].set_title('Calculate Gaussian KDE')
axes[3].pcolormesh(xi, yi, zi.reshape(xi.shape), cmap=plt.cm.BuGn_r)
axes[3].contour(xi, yi, zi.reshape(xi.shape))
# axes[3].pcolormesh(xi, yi, zi.reshape(xi.shape), cmap=plt.cm.BuGn_r)

# add shading
# axes[4].set_title('2D Density with shading')
# axes[4].pcolormesh(xi, yi, zi.reshape(xi.shape), shading='gouraud', cmap=plt.cm.BuGn_r)

# contour
# axes[5].set_title('Contour')
# axes[5].pcolormesh(xi, yi, zi.reshape(xi.shape), shading='gouraud', cmap=plt.cm.BuGn_r)
# axes[5].contour(xi, yi, zi.reshape(xi.shape))
# Out:
# <matplotlib.backends._backend_agg.RendererAgg object at 0x7fa22fe4a150>
# draw_quad_mesh
# gc: <matplotlib.backend_bases.GraphicsContextBase object at 0x7fa22da2e6d8>
# Methods: ['__class__', '__delattr__', '__dir__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'copy_properties', 'get_alpha', 'get_antialiased', 'get_capstyle', 'get_clip_path', 'get_clip_rectangle', 'get_dashes', 'get_forced_alpha', 'get_gid', 'get_hatch', 'get_hatch_color', 'get_hatch_linewidth', 'get_hatch_path', 'get_joinstyle', 'get_linewidth', 'get_rgb', 'get_sketch_params', 'get_snap', 'get_url', 'restore', 'set_alpha', 'set_antialiased', 'set_capstyle', 'set_clip_path', 'set_clip_rectangle', 'set_dashes', 'set_foreground', 'set_gid', 'set_hatch', 'set_hatch_color', 'set_joinstyle', 'set_linewidth', 'set_sketch_params', 'set_snap', 'set_url']
# rgb: (0.0, 0.0, 0.0, 1.0)
# Cmap: True
# Renderer: <matplotlib.backends.backend_agg.RendererAgg object at 0x7fa2604670f0>
# Methods: ['__class__', '__delattr__', '__dir__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setstate__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_draw_text_as_path', '_get_agg_font', '_get_text_path_transform', '_iter_collection', '_iter_collection_raw_paths', '_iter_collection_uses_per_path', '_update_methods', 'buffer_rgba', 'clear', 'close_group', 'copy_from_bbox', 'draw_gouraud_triangle', 'draw_gouraud_triangles', 'draw_image', 'draw_markers', 'draw_mathtext', 'draw_path', 'draw_path_collection', 'draw_quad_mesh', 'draw_tex', 'draw_text', 'flipy', 'get_canvas_width_height', 'get_content_extents', 'get_image_magnification', 'get_texmanager', 'get_text_width_height_descent', 'new_gc', 'open_group', 'option_image_nocomposite', 'option_scale_image', 'points_to_pixels', 'restore_region', 'start_filter', 'start_rasterizing', 'stop_filter', 'stop_rasterizing', 'strip_math', 'tostring_argb', 'tostring_rgb', 'tostring_rgba_minimized']
# draw_quad_mesh
# gc: <matplotlib.backend_bases.GraphicsContextBase object at 0x7fa2301a91d0>
# Methods: ['__class__', '__delattr__', '__dir__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'copy_properties', 'get_alpha', 'get_antialiased', 'get_capstyle', 'get_clip_path', 'get_clip_rectangle', 'get_dashes', 'get_forced_alpha', 'get_gid', 'get_hatch', 'get_hatch_color', 'get_hatch_linewidth', 'get_hatch_path', 'get_joinstyle', 'get_linewidth', 'get_rgb', 'get_sketch_params', 'get_snap', 'get_url', 'restore', 'set_alpha', 'set_antialiased', 'set_capstyle', 'set_clip_path', 'set_clip_rectangle', 'set_dashes', 'set_foreground', 'set_gid', 'set_hatch', 'set_hatch_color', 'set_joinstyle', 'set_linewidth', 'set_sketch_params', 'set_snap', 'set_url']
# rgb: (0.0, 0.0, 0.0, 1.0)
# Cmap: True
# Renderer: <matplotlib.backends.backend_agg.RendererAgg object at 0x7fa2604670f0>
# Methods: ['__class__', '__delattr__', '__dir__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setstate__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_draw_text_as_path', '_get_agg_font', '_get_text_path_transform', '_iter_collection', '_iter_collection_raw_paths', '_iter_collection_uses_per_path', '_update_methods', 'buffer_rgba', 'clear', 'close_group', 'copy_from_bbox', 'draw_gouraud_triangle', 'draw_gouraud_triangles', 'draw_image', 'draw_markers', 'draw_mathtext', 'draw_path', 'draw_path_collection', 'draw_quad_mesh', 'draw_tex', 'draw_text', 'flipy', 'get_canvas_width_height', 'get_content_extents', 'get_image_magnification', 'get_texmanager', 'get_text_width_height_descent', 'new_gc', 'open_group', 'option_image_nocomposite', 'option_scale_image', 'points_to_pixels', 'restore_region', 'start_filter', 'start_rasterizing', 'stop_filter', 'stop_rasterizing', 'strip_math', 'tostring_argb', 'tostring_rgb', 'tostring_rgba_minimized']
# <matplotlib.backends._backend_agg.RendererAgg object at 0x7fa2301b0930>
# draw_quad_mesh
# gc: <matplotlib.backend_bases.GraphicsContextBase object at 0x7fa22da08438>
# Methods: ['__class__', '__delattr__', '__dir__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'copy_properties', 'get_alpha', 'get_antialiased', 'get_capstyle', 'get_clip_path', 'get_clip_rectangle', 'get_dashes', 'get_forced_alpha', 'get_gid', 'get_hatch', 'get_hatch_color', 'get_hatch_linewidth', 'get_hatch_path', 'get_joinstyle', 'get_linewidth', 'get_rgb', 'get_sketch_params', 'get_snap', 'get_url', 'restore', 'set_alpha', 'set_antialiased', 'set_capstyle', 'set_clip_path', 'set_clip_rectangle', 'set_dashes', 'set_foreground', 'set_gid', 'set_hatch', 'set_hatch_color', 'set_joinstyle', 'set_linewidth', 'set_sketch_params', 'set_snap', 'set_url']
# rgb: (0.0, 0.0, 0.0, 1.0)
# Cmap: True
# Renderer: <matplotlib.backends.backend_agg.RendererAgg object at 0x7fa22da4f7f0>
# Methods: ['__class__', '__delattr__', '__dir__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setstate__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_draw_text_as_path', '_get_agg_font', '_get_text_path_transform', '_iter_collection', '_iter_collection_raw_paths', '_iter_collection_uses_per_path', '_update_methods', 'buffer_rgba', 'clear', 'close_group', 'copy_from_bbox', 'draw_gouraud_triangle', 'draw_gouraud_triangles', 'draw_image', 'draw_markers', 'draw_mathtext', 'draw_path', 'draw_path_collection', 'draw_quad_mesh', 'draw_tex', 'draw_text', 'flipy', 'get_canvas_width_height', 'get_content_extents', 'get_image_magnification', 'get_texmanager', 'get_text_width_height_descent', 'new_gc', 'open_group', 'option_image_nocomposite', 'option_scale_image', 'points_to_pixels', 'restore_region', 'start_filter', 'start_rasterizing', 'stop_filter', 'stop_rasterizing', 'strip_math', 'tostring_argb', 'tostring_rgb', 'tostring_rgba_minimized']
